# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML321ENSkillsNetwork817-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Clustering based Course Recommender System**

# %% [markdown]
# Estimated time needed: **90** minutes

# %% [markdown]
# Previously, we have generated user profile vectors based on course ratings and genres.
#
# A user profile vector may look like a row vector in the following matrix, for example, we can see the Database column for user2 has a value 1 which means user2 is very interesting in courses related to the databases. With the user profile vectors generated, we can also easily compute the similarity among users based on their shared interests.

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/userprofiles.png)

# %% [markdown]
# Furthermore, we could perform clustering algorithms such as K-means or DBSCAN to group users with similar learning interests. For example, in the below user clusters, we have user clusters whom have learned courses related to machine learning, cloud computing, databases, and web development, etc.

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/userprofiles_clustering.png)

# %% [markdown]
# For each user group, we can come up with a list of popular courses. For example, for the machine learning user cluster/learning group, we can count the most frequently enrolled courses, which are very likely to be the most popular and good machine learning courses because they are enrolled by many users who are interested in machine learning.
#
# If we know a user belongs to the machine learning group, we may recommend the most enrolled courses to them and it is very likely the user will be interested in them.

# %% [markdown]
# Next in this lab, you will be implementing some clustering-based recommender system algorithms.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# * Perform k-means clustering on the original user profile feature vectors
# * Apply PCA (Principle Component Analysis ) on user profile feature vectors to reduce dimensions
# * Perform k-means clustering on the PCA transformed main components
# * Generate course recommendations based on other group members' enrollment history

# %% [markdown]
# ----

# %% [markdown]
# ## Prepare and setup lab environment

# %% [markdown]
# First install and import required libraries:

# %%
# !pip install scikit-learn==1.0.2
# !pip install seaborn==0.11.1
# Out:
# Collecting scikit-learn==1.0.2
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [66 lines of output]
#       Partial import of sklearn during the build process.
#       setup.py:128: DeprecationWarning:
#
#         `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#         of the deprecation of `distutils` itself. It will be removed for
#         Python >= 3.12. For older Python versions it will remain present.
#         It is recommended to use `setuptools < 60.0` for those Python versions.
#         For more details, see:
#           https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#         from numpy.distutils.command.build_ext import build_ext  # noqa
#       INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       Traceback (most recent call last):
#         File "C:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#         File "C:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 149, in prepare_metadata_for_build_wheel
#           return hook(metadata_directory, config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-build-env-nkg594rt\overlay\Lib\site-packages\setuptools\build_meta.py", line 174, in prepare_metadata_for_build_wheel
#           self.run_setup()
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-build-env-nkg594rt\overlay\Lib\site-packages\setuptools\build_meta.py", line 268, in run_setup
#           self).run_setup(setup_script=setup_script)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-build-env-nkg594rt\overlay\Lib\site-packages\setuptools\build_meta.py", line 158, in run_setup
#           exec(compile(code, __file__, 'exec'), locals())
#         File "setup.py", line 319, in <module>
#           setup_package()
#         File "setup.py", line 315, in setup_package
#           setup(**metadata)
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-build-env-nkg594rt\overlay\Lib\site-packages\numpy\distutils\core.py", line 135, in setup
#           config = configuration()
#                    ^^^^^^^^^^^^^^^
#         File "setup.py", line 201, in configuration
#           config.add_subpackage("sklearn")
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-build-env-nkg594rt\overlay\Lib\site-packages\numpy\distutils\misc_util.py", line 1050, in add_subpackage
#           config_list = self.get_subpackage(subpackage_name, subpackage_path,
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-build-env-nkg594rt\overlay\Lib\site-packages\numpy\distutils\misc_util.py", line 1016, in get_subpackage
#           config = self._get_configuration_from_setup_py(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-build-env-nkg594rt\overlay\Lib\site-packages\numpy\distutils\misc_util.py", line 958, in _get_configuration_from_setup_py
#           config = setup_module.configuration(*args)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-install-03agcua9\scikit-learn_3e3df5ed0087485ca6439951915fb96e\sklearn\setup.py", line 85, in configuration
#           cythonize_extensions(top_path, config)
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-install-03agcua9\scikit-learn_3e3df5ed0087485ca6439951915fb96e\sklearn\_build_utils\__init__.py", line 47, in cythonize_extensions
#           basic_check_build()
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-install-03agcua9\scikit-learn_3e3df5ed0087485ca6439951915fb96e\sklearn\_build_utils\pre_build_helpers.py", line 114, in basic_check_build
#           compile_test_program(code)
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-install-03agcua9\scikit-learn_3e3df5ed0087485ca6439951915fb96e\sklearn\_build_utils\pre_build_helpers.py", line 70, in compile_test_program
#           ccompiler.compile(
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-build-env-nkg594rt\overlay\Lib\site-packages\setuptools\_distutils\_msvccompiler.py", line 327, in compile
#           self.initialize()
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-build-env-nkg594rt\overlay\Lib\site-packages\setuptools\_distutils\_msvccompiler.py", line 224, in initialize
#           vc_env = _get_vc_env(plat_spec)
#                    ^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-build-env-nkg594rt\overlay\Lib\site-packages\setuptools\msvc.py", line 316, in msvc14_get_vc_env
#           return _msvc14_get_vc_env(plat_spec)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\SnappMarket\AppData\Local\Temp\pip-build-env-nkg594rt\overlay\Lib\site-packages\setuptools\msvc.py", line 270, in _msvc14_get_vc_env
#           raise distutils.errors.DistutilsPlatformError(
#       distutils.errors.DistutilsPlatformError: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
#   Downloading scikit-learn-1.0.2.tar.gz (6.7 MB)
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.7 MB 43.8 kB/s eta 0:02:33
#      ---------------------------------------- 0.0/6.7 MB 43.8 kB/s eta 0:02:33
#      ---------------------------------------- 0.0/6.7 MB 43.8 kB/s eta 0:02:33
#      ---------------------------------------- 0.0/6.7 MB 48.0 kB/s eta 0:02:20
#      ---------------------------------------- 0.0/6.7 MB 48.0 kB/s eta 0:02:20
#      ---------------------------------------- 0.1/6.7 MB 72.8 kB/s eta 0:01:32
#      ---------------------------------------- 0.1/6.7 MB 72.8 kB/s eta 0:01:32
#      ---------------------------------------- 0.1/6.7 MB 75.7 kB/s eta 0:01:28
#      ---------------------------------------- 0.1/6.7 MB 75.7 kB/s eta 0:01:28
#       --------------------------------------- 0.1/6.7 MB 90.4 kB/s eta 0:01:14
#       --------------------------------------- 0.1/6.7 MB 90.4 kB/s eta 0:01:14
#       --------------------------------------- 0.1/6.7 MB 102.4 kB/s eta 0:01:05
#       --------------------------------------- 0.1/6.7 MB 102.4 kB/s eta 0:01:05
#       --------------------------------------- 0.1/6.7 MB 106.1 kB/s eta 0:01:03
#       --------------------------------------- 0.1/6.7 MB 116.8 kB/s eta 0:00:57
#       --------------------------------------- 0.1/6.7 MB 116.8 kB/s eta 0:00:57
#       --------------------------------------- 0.2/6.7 MB 117.7 kB/s eta 0:00:56
#      - -------------------------------------- 0.2/6.7 MB 127.9 kB/s eta 0:00:52
#      - -------------------------------------- 0.2/6.7 MB 137.2 kB/s eta 0:00:48
#      - -------------------------------------- 0.2/6.7 MB 137.2 kB/s eta 0:00:48
#      - -------------------------------------- 0.2/6.7 MB 137.2 kB/s eta 0:00:48
#      - -------------------------------------- 0.2/6.7 MB 137.2 kB/s eta 0:00:48
#      - -------------------------------------- 0.2/6.7 MB 137.2 kB/s eta 0:00:48
#      - -------------------------------------- 0.2/6.7 MB 139.0 kB/s eta 0:00:47
#      - -------------------------------------- 0.2/6.7 MB 141.4 kB/s eta 0:00:46
#      - -------------------------------------- 0.2/6.7 MB 141.4 kB/s eta 0:00:46
#      - -------------------------------------- 0.3/6.7 MB 147.0 kB/s eta 0:00:44
#      - -------------------------------------- 0.3/6.7 MB 147.0 kB/s eta 0:00:44
#      - -------------------------------------- 0.3/6.7 MB 150.8 kB/s eta 0:00:43
#      - -------------------------------------- 0.3/6.7 MB 150.0 kB/s eta 0:00:43
#      - -------------------------------------- 0.3/6.7 MB 150.0 kB/s eta 0:00:43
#      - -------------------------------------- 0.3/6.7 MB 150.0 kB/s eta 0:00:43
#      - -------------------------------------- 0.3/6.7 MB 150.9 kB/s eta 0:00:43
#      - -------------------------------------- 0.3/6.7 MB 150.9 kB/s eta 0:00:43
#      - -------------------------------------- 0.3/6.7 MB 150.1 kB/s eta 0:00:43
#      - -------------------------------------- 0.3/6.7 MB 150.1 kB/s eta 0:00:43
#      -- ------------------------------------- 0.3/6.7 MB 152.0 kB/s eta 0:00:42
#      -- ------------------------------------- 0.3/6.7 MB 152.0 kB/s eta 0:00:42
#      -- ------------------------------------- 0.3/6.7 MB 152.0 kB/s eta 0:00:42
#      -- ------------------------------------- 0.3/6.7 MB 152.0 kB/s eta 0:00:42
#      -- ------------------------------------- 0.3/6.7 MB 152.0 kB/s eta 0:00:42
#      -- ------------------------------------- 0.3/6.7 MB 152.0 kB/s eta 0:00:42
#      -- ------------------------------------- 0.4/6.7 MB 154.5 kB/s eta 0:00:41
#      -- ------------------------------------- 0.4/6.7 MB 154.5 kB/s eta 0:00:41
#      -- ------------------------------------- 0.4/6.7 MB 154.7 kB/s eta 0:00:41
#      -- ------------------------------------- 0.4/6.7 MB 154.7 kB/s eta 0:00:41
#      -- ------------------------------------- 0.4/6.7 MB 151.3 kB/s eta 0:00:42
#      -- ------------------------------------- 0.4/6.7 MB 151.3 kB/s eta 0:00:42
#      -- ------------------------------------- 0.4/6.7 MB 151.3 kB/s eta 0:00:42
#      -- ------------------------------------- 0.4/6.7 MB 152.7 kB/s eta 0:00:42
#      -- ------------------------------------- 0.4/6.7 MB 152.7 kB/s eta 0:00:42
#      -- ------------------------------------- 0.5/6.7 MB 155.7 kB/s eta 0:00:41
#      -- ------------------------------------- 0.5/6.7 MB 155.7 kB/s eta 0:00:41
#      -- ------------------------------------- 0.5/6.7 MB 152.6 kB/s eta 0:00:41
#      -- ------------------------------------- 0.5/6.7 MB 152.6 kB/s eta 0:00:41
#      -- ------------------------------------- 0.5/6.7 MB 154.6 kB/s eta 0:00:41
#      -- ------------------------------------- 0.5/6.7 MB 154.6 kB/s eta 0:00:41
#      -- ------------------------------------- 0.5/6.7 MB 154.0 kB/s eta 0:00:41
#      -- ------------------------------------- 0.5/6.7 MB 154.0 kB/s eta 0:00:41
#      --- ------------------------------------ 0.5/6.7 MB 155.9 kB/s eta 0:00:40
#      --- ------------------------------------ 0.5/6.7 MB 155.9 kB/s eta 0:00:40
#      --- ------------------------------------ 0.5/6.7 MB 158.4 kB/s eta 0:00:40
#      --- ------------------------------------ 0.5/6.7 MB 158.4 kB/s eta 0:00:40
#      --- ------------------------------------ 0.5/6.7 MB 158.4 kB/s eta 0:00:40
#      --- ------------------------------------ 0.5/6.7 MB 158.4 kB/s eta 0:00:40
#      --- ------------------------------------ 0.5/6.7 MB 158.4 kB/s eta 0:00:40
#      --- ------------------------------------ 0.5/6.7 MB 158.4 kB/s eta 0:00:40
#      --- ------------------------------------ 0.5/6.7 MB 147.5 kB/s eta 0:00:42
#      --- ------------------------------------ 0.6/6.7 MB 151.9 kB/s eta 0:00:41
#      --- ------------------------------------ 0.6/6.7 MB 151.9 kB/s eta 0:00:41
#      --- ------------------------------------ 0.6/6.7 MB 151.9 kB/s eta 0:00:41
#      --- ------------------------------------ 0.6/6.7 MB 149.0 kB/s eta 0:00:42
#      --- ------------------------------------ 0.6/6.7 MB 149.0 kB/s eta 0:00:42
#      --- ------------------------------------ 0.6/6.7 MB 149.0 kB/s eta 0:00:42
#      --- ------------------------------------ 0.6/6.7 MB 148.8 kB/s eta 0:00:42
#      --- ------------------------------------ 0.6/6.7 MB 148.8 kB/s eta 0:00:42
#      --- ------------------------------------ 0.6/6.7 MB 148.8 kB/s eta 0:00:42
#      --- ------------------------------------ 0.6/6.7 MB 149.3 kB/s eta 0:00:41
#      --- ------------------------------------ 0.6/6.7 MB 149.3 kB/s eta 0:00:41
#      --- ------------------------------------ 0.6/6.7 MB 147.8 kB/s eta 0:00:42
#      --- ------------------------------------ 0.6/6.7 MB 147.8 kB/s eta 0:00:42
#      --- ------------------------------------ 0.6/6.7 MB 147.8 kB/s eta 0:00:42
#      --- ------------------------------------ 0.6/6.7 MB 147.8 kB/s eta 0:00:42
#      --- ------------------------------------ 0.6/6.7 MB 147.8 kB/s eta 0:00:42
#      --- ------------------------------------ 0.6/6.7 MB 144.6 kB/s eta 0:00:42
#      --- ------------------------------------ 0.7/6.7 MB 145.4 kB/s eta 0:00:42
#      --- ------------------------------------ 0.7/6.7 MB 145.4 kB/s eta 0:00:42
#      --- ------------------------------------ 0.7/6.7 MB 145.4 kB/s eta 0:00:42
#      --- ------------------------------------ 0.7/6.7 MB 145.4 kB/s eta 0:00:42
#      ---- ----------------------------------- 0.7/6.7 MB 144.9 kB/s eta 0:00:42
#      ---- ----------------------------------- 0.7/6.7 MB 144.9 kB/s eta 0:00:42
#      ---- ----------------------------------- 0.7/6.7 MB 144.9 kB/s eta 0:00:42
#      ---- ----------------------------------- 0.7/6.7 MB 144.9 kB/s eta 0:00:42
#      ---- ----------------------------------- 0.7/6.7 MB 143.0 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.7/6.7 MB 143.0 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.7/6.7 MB 141.9 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.7/6.7 MB 141.9 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.7/6.7 MB 141.9 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.7/6.7 MB 142.0 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.7/6.7 MB 142.0 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.7/6.7 MB 142.0 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.7/6.7 MB 142.0 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.7/6.7 MB 142.0 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.7/6.7 MB 142.0 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.8/6.7 MB 141.1 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.8/6.7 MB 141.1 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.8/6.7 MB 141.1 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.8/6.7 MB 140.8 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.8/6.7 MB 140.8 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.8/6.7 MB 140.8 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.8/6.7 MB 140.8 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.8/6.7 MB 138.4 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.8/6.7 MB 138.4 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.8/6.7 MB 138.4 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.8/6.7 MB 138.2 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.8/6.7 MB 138.2 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.8/6.7 MB 138.2 kB/s eta 0:00:43
#      ---- ----------------------------------- 0.8/6.7 MB 137.0 kB/s eta 0:00:44
#      ---- ----------------------------------- 0.8/6.7 MB 137.0 kB/s eta 0:00:44
#      ---- ----------------------------------- 0.8/6.7 MB 137.0 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.8/6.7 MB 137.2 kB/s eta 0:00:43
#      ----- ---------------------------------- 0.8/6.7 MB 137.2 kB/s eta 0:00:43
#      ----- ---------------------------------- 0.8/6.7 MB 137.2 kB/s eta 0:00:43
#      ----- ---------------------------------- 0.9/6.7 MB 137.7 kB/s eta 0:00:43
#      ----- ---------------------------------- 0.9/6.7 MB 137.7 kB/s eta 0:00:43
#      ----- ---------------------------------- 0.9/6.7 MB 137.7 kB/s eta 0:00:43
#      ----- ---------------------------------- 0.9/6.7 MB 135.9 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 135.9 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 135.9 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 135.9 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 135.9 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 134.5 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 134.5 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 133.8 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 133.8 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 133.8 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 133.8 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 132.9 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 132.9 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 132.9 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 132.9 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 132.2 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 132.2 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 132.2 kB/s eta 0:00:44
#      ----- ---------------------------------- 0.9/6.7 MB 132.2 kB/s eta 0:00:44
#      ----- ---------------------------------- 1.0/6.7 MB 131.1 kB/s eta 0:00:44
#      ----- ---------------------------------- 1.0/6.7 MB 131.1 kB/s eta 0:00:44
#      ----- ---------------------------------- 1.0/6.7 MB 131.1 kB/s eta 0:00:44
#      ----- ---------------------------------- 1.0/6.7 MB 131.1 kB/s eta 0:00:44
#      ----- ---------------------------------- 1.0/6.7 MB 131.1 kB/s eta 0:00:44
#      ----- ---------------------------------- 1.0/6.7 MB 129.2 kB/s eta 0:00:45
#      ----- ---------------------------------- 1.0/6.7 MB 129.7 kB/s eta 0:00:45
#      ----- ---------------------------------- 1.0/6.7 MB 129.7 kB/s eta 0:00:45
#      ----- ---------------------------------- 1.0/6.7 MB 129.7 kB/s eta 0:00:45
#      ----- ---------------------------------- 1.0/6.7 MB 129.7 kB/s eta 0:00:45
#      ----- ---------------------------------- 1.0/6.7 MB 129.7 kB/s eta 0:00:45
#      ----- ---------------------------------- 1.0/6.7 MB 127.1 kB/s eta 0:00:46
#      ----- ---------------------------------- 1.0/6.7 MB 127.1 kB/s eta 0:00:46
#      ----- ---------------------------------- 1.0/6.7 MB 127.1 kB/s eta 0:00:46
#      ----- ---------------------------------- 1.0/6.7 MB 127.1 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 126.7 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 126.7 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 126.7 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 127.0 kB/s eta 0:00:45
#      ------ --------------------------------- 1.0/6.7 MB 127.0 kB/s eta 0:00:45
#      ------ --------------------------------- 1.0/6.7 MB 127.0 kB/s eta 0:00:45
#      ------ --------------------------------- 1.0/6.7 MB 127.0 kB/s eta 0:00:45
#      ------ --------------------------------- 1.0/6.7 MB 127.0 kB/s eta 0:00:45
#      ------ --------------------------------- 1.0/6.7 MB 127.0 kB/s eta 0:00:45
#      ------ --------------------------------- 1.0/6.7 MB 124.4 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 124.4 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 124.4 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 124.4 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 124.4 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 124.4 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 124.4 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 124.4 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 124.4 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 124.4 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 124.4 kB/s eta 0:00:46
#      ------ --------------------------------- 1.0/6.7 MB 124.4 kB/s eta 0:00:46
#      ------ --------------------------------- 1.1/6.7 MB 119.1 kB/s eta 0:00:48
#      ------ --------------------------------- 1.1/6.7 MB 119.1 kB/s eta 0:00:48
#      ------ --------------------------------- 1.1/6.7 MB 119.1 kB/s eta 0:00:48
#      ------ --------------------------------- 1.1/6.7 MB 119.1 kB/s eta 0:00:48
#      ------ --------------------------------- 1.1/6.7 MB 119.1 kB/s eta 0:00:48
#      ------ --------------------------------- 1.1/6.7 MB 119.1 kB/s eta 0:00:48
#      ------ --------------------------------- 1.1/6.7 MB 119.1 kB/s eta 0:00:48
#      ------ --------------------------------- 1.1/6.7 MB 119.1 kB/s eta 0:00:48
#      ------ --------------------------------- 1.1/6.7 MB 119.1 kB/s eta 0:00:48
#      ------ --------------------------------- 1.1/6.7 MB 119.1 kB/s eta 0:00:48
#      ------ --------------------------------- 1.1/6.7 MB 119.1 kB/s eta 0:00:48
#      ------ --------------------------------- 1.1/6.7 MB 119.1 kB/s eta 0:00:48
#      ------ --------------------------------- 1.1/6.7 MB 119.1 kB/s eta 0:00:48
#      ------ --------------------------------- 1.1/6.7 MB 112.5 kB/s eta 0:00:51
#      ------ --------------------------------- 1.1/6.7 MB 112.5 kB/s eta 0:00:51
#      ------ --------------------------------- 1.1/6.7 MB 112.5 kB/s eta 0:00:51
#      ------ --------------------------------- 1.1/6.7 MB 112.5 kB/s eta 0:00:51
#      ------ --------------------------------- 1.1/6.7 MB 112.5 kB/s eta 0:00:51
#      ------ --------------------------------- 1.1/6.7 MB 112.5 kB/s eta 0:00:51
#      ------ --------------------------------- 1.1/6.7 MB 112.5 kB/s eta 0:00:51
#      ------ --------------------------------- 1.1/6.7 MB 112.5 kB/s eta 0:00:51
#      ------ --------------------------------- 1.1/6.7 MB 110.1 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 110.1 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 110.1 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 110.1 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 110.1 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 110.1 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 110.1 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 110.1 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 110.1 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 107.7 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 107.7 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 107.7 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 107.7 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 107.7 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 107.7 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 107.7 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 107.7 kB/s eta 0:00:52
#      ------ --------------------------------- 1.1/6.7 MB 104.9 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 104.9 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 104.9 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 104.9 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 104.9 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 104.9 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 104.9 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 104.9 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.1/6.7 MB 103.2 kB/s eta 0:00:54
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------ --------------------------------- 1.2/6.7 MB 96.1 kB/s eta 0:00:58
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 89.4 kB/s eta 0:01:02
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 85.7 kB/s eta 0:01:05
#      ------- -------------------------------- 1.2/6.7 MB 76.9 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.9 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.9 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.9 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.9 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.9 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.9 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.9 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.2 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.2 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.2 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.2 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.2 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.2 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.2 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.2 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.2 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 76.2 kB/s eta 0:01:12
#      ------- -------------------------------- 1.2/6.7 MB 74.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.2/6.7 MB 74.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.2/6.7 MB 74.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.2/6.7 MB 74.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.2/6.7 MB 74.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.2/6.7 MB 74.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.2/6.7 MB 74.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.2/6.7 MB 74.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.2/6.7 MB 74.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 74.2 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 74.2 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 74.2 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 74.2 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 74.2 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 74.2 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 74.2 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 74.2 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 73.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 73.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 73.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 73.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 73.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 73.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 73.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 73.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 73.8 kB/s eta 0:01:14
#      ------- -------------------------------- 1.3/6.7 MB 72.6 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.6 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.6 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.6 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.6 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.6 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.6 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.4 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.4 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.4 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.4 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.4 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.4 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.4 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.4 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.4 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 72.4 kB/s eta 0:01:15
#      ------- -------------------------------- 1.3/6.7 MB 71.2 kB/s eta 0:01:16
#      ------- -------------------------------- 1.3/6.7 MB 71.2 kB/s eta 0:01:16
#      ------- -------------------------------- 1.3/6.7 MB 71.2 kB/s eta 0:01:16
#      ------- -------------------------------- 1.3/6.7 MB 71.2 kB/s eta 0:01:16
#      ------- -------------------------------- 1.3/6.7 MB 71.2 kB/s eta 0:01:16
#      ------- -------------------------------- 1.3/6.7 MB 71.2 kB/s eta 0:01:16
#      ------- -------------------------------- 1.3/6.7 MB 71.2 kB/s eta 0:01:16
#      ------- -------------------------------- 1.3/6.7 MB 70.9 kB/s eta 0:01:16
#      ------- -------------------------------- 1.3/6.7 MB 70.9 kB/s eta 0:01:16
#      ------- -------------------------------- 1.3/6.7 MB 70.9 kB/s eta 0:01:16
#      ------- -------------------------------- 1.3/6.7 MB 70.9 kB/s eta 0:01:16
#      ------- -------------------------------- 1.3/6.7 MB 70.9 kB/s eta 0:01:16
#      ------- -------------------------------- 1.3/6.7 MB 70.9 kB/s eta 0:01:16
#      ------- -------------------------------- 1.3/6.7 MB 70.9 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.8 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.8 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.8 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.8 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.8 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.8 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.4 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.4 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.4 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.4 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.4 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.6 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.6 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.6 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.6 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.6 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.2 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.2 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.2 kB/s eta 0:01:16
#      -------- ------------------------------- 1.4/6.7 MB 70.7 kB/s eta 0:01:15
#      -------- ------------------------------- 1.4/6.7 MB 70.7 kB/s eta 0:01:15
#      -------- ------------------------------- 1.4/6.7 MB 70.7 kB/s eta 0:01:15
#      -------- ------------------------------- 1.4/6.7 MB 70.7 kB/s eta 0:01:15
#      -------- ------------------------------- 1.4/6.7 MB 70.7 kB/s eta 0:01:15
#      -------- ------------------------------- 1.4/6.7 MB 71.0 kB/s eta 0:01:15
#      -------- ------------------------------- 1.4/6.7 MB 71.0 kB/s eta 0:01:15
#      -------- ------------------------------- 1.4/6.7 MB 71.0 kB/s eta 0:01:15
#      -------- ------------------------------- 1.4/6.7 MB 71.0 kB/s eta 0:01:15
#      -------- ------------------------------- 1.4/6.7 MB 71.0 kB/s eta 0:01:15
#      -------- ------------------------------- 1.5/6.7 MB 70.6 kB/s eta 0:01:15
#      -------- ------------------------------- 1.5/6.7 MB 70.6 kB/s eta 0:01:15
#      -------- ------------------------------- 1.5/6.7 MB 70.6 kB/s eta 0:01:15
#      -------- ------------------------------- 1.5/6.7 MB 70.6 kB/s eta 0:01:15
#      -------- ------------------------------- 1.5/6.7 MB 70.9 kB/s eta 0:01:14
#      -------- ------------------------------- 1.5/6.7 MB 70.9 kB/s eta 0:01:14
#      -------- ------------------------------- 1.5/6.7 MB 70.9 kB/s eta 0:01:14
#      -------- ------------------------------- 1.5/6.7 MB 70.9 kB/s eta 0:01:14
#      -------- ------------------------------- 1.5/6.7 MB 71.0 kB/s eta 0:01:14
#      -------- ------------------------------- 1.5/6.7 MB 71.0 kB/s eta 0:01:14
#      -------- ------------------------------- 1.5/6.7 MB 71.0 kB/s eta 0:01:14
#      -------- ------------------------------- 1.5/6.7 MB 71.0 kB/s eta 0:01:14
#      -------- ------------------------------- 1.5/6.7 MB 71.0 kB/s eta 0:01:14
#      -------- ------------------------------- 1.5/6.7 MB 70.6 kB/s eta 0:01:14
#      -------- ------------------------------- 1.5/6.7 MB 70.6 kB/s eta 0:01:14
#      -------- ------------------------------- 1.5/6.7 MB 70.6 kB/s eta 0:01:14
#      -------- ------------------------------- 1.5/6.7 MB 70.6 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.9 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.9 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.9 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.9 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.9 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.9 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.9 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.9 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.9 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.5 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.5 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.5 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.5 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.5 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.5 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.5 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.0 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.0 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.0 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.0 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.0 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.0 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.0 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.0 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.0 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.0 kB/s eta 0:01:14
#      --------- ------------------------------ 1.5/6.7 MB 70.0 kB/s eta 0:01:14
#      --------- ------------------------------ 1.6/6.7 MB 69.3 kB/s eta 0:01:15
#      --------- ------------------------------ 1.6/6.7 MB 69.3 kB/s eta 0:01:15
#      --------- ------------------------------ 1.6/6.7 MB 69.3 kB/s eta 0:01:15
#      --------- ------------------------------ 1.6/6.7 MB 69.3 kB/s eta 0:01:15
#      --------- ------------------------------ 1.6/6.7 MB 69.3 kB/s eta 0:01:15
#      --------- ------------------------------ 1.6/6.7 MB 69.3 kB/s eta 0:01:15
#      --------- ------------------------------ 1.6/6.7 MB 69.3 kB/s eta 0:01:15
#      --------- ------------------------------ 1.6/6.7 MB 69.3 kB/s eta 0:01:15
#      --------- ------------------------------ 1.6/6.7 MB 69.3 kB/s eta 0:01:15
#      --------- ------------------------------ 1.6/6.7 MB 69.3 kB/s eta 0:01:15
#      --------- ------------------------------ 1.6/6.7 MB 68.3 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.3 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.3 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.3 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.3 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.3 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.3 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.3 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.0 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.0 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.0 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.0 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.0 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.0 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.0 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 68.0 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.9 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.9 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.9 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.9 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.9 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.9 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.9 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.9 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.2 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.2 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.2 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.2 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.2 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.4 kB/s eta 0:01:16
#      --------- ------------------------------ 1.6/6.7 MB 67.4 kB/s eta 0:01:16
# ...
#      -------------------------------------- - 6.4/6.7 MB 34.9 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.9 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.9 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.9 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.9 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.9 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.9 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.9 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.9 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.9 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.9 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.9 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.9 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.6 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.6 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.6 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.6 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.6 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.6 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.6 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.6 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.6 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.6 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.6 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.6 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.6 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.6 kB/s eta 0:00:09
#      -------------------------------------- - 6.4/6.7 MB 34.5 kB/s eta 0:00:08
#      -------------------------------------- - 6.4/6.7 MB 34.5 kB/s eta 0:00:08
#      -------------------------------------- - 6.4/6.7 MB 34.5 kB/s eta 0:00:08
#      -------------------------------------- - 6.4/6.7 MB 34.5 kB/s eta 0:00:08
#      -------------------------------------- - 6.4/6.7 MB 34.5 kB/s eta 0:00:08
#      -------------------------------------- - 6.4/6.7 MB 34.5 kB/s eta 0:00:08
#      -------------------------------------- - 6.4/6.7 MB 34.5 kB/s eta 0:00:08
#      -------------------------------------- - 6.4/6.7 MB 34.5 kB/s eta 0:00:08
#      -------------------------------------- - 6.4/6.7 MB 34.5 kB/s eta 0:00:08
#      -------------------------------------- - 6.5/6.7 MB 35.0 kB/s eta 0:00:08
#      -------------------------------------- - 6.5/6.7 MB 35.0 kB/s eta 0:00:08
#      -------------------------------------- - 6.5/6.7 MB 35.0 kB/s eta 0:00:08
#      -------------------------------------- - 6.5/6.7 MB 35.0 kB/s eta 0:00:08
#      -------------------------------------- - 6.5/6.7 MB 35.0 kB/s eta 0:00:08
#      -------------------------------------- - 6.5/6.7 MB 35.0 kB/s eta 0:00:08
#      -------------------------------------- - 6.5/6.7 MB 35.1 kB/s eta 0:00:07
#      -------------------------------------- - 6.5/6.7 MB 35.1 kB/s eta 0:00:07
#      -------------------------------------- - 6.5/6.7 MB 35.1 kB/s eta 0:00:07
#      -------------------------------------- - 6.5/6.7 MB 35.1 kB/s eta 0:00:07
#      -------------------------------------- - 6.5/6.7 MB 35.1 kB/s eta 0:00:07
#      -------------------------------------- - 6.5/6.7 MB 35.1 kB/s eta 0:00:07
#      -------------------------------------- - 6.5/6.7 MB 35.2 kB/s eta 0:00:07
#      -------------------------------------- - 6.5/6.7 MB 35.2 kB/s eta 0:00:07
#      -------------------------------------- - 6.5/6.7 MB 35.2 kB/s eta 0:00:07
#      -------------------------------------- - 6.5/6.7 MB 35.2 kB/s eta 0:00:07
#      -------------------------------------- - 6.5/6.7 MB 35.2 kB/s eta 0:00:07
#      -------------------------------------- - 6.5/6.7 MB 35.2 kB/s eta 0:00:07
#      -------------------------------------- - 6.5/6.7 MB 35.2 kB/s eta 0:00:07
#      -------------------------------------- - 6.5/6.7 MB 35.5 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 35.5 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 35.5 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 35.5 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 35.5 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 35.5 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 35.5 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 35.5 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 35.5 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 35.5 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 35.5 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 35.5 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 36.2 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 36.2 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 36.2 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 36.2 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 36.2 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 36.2 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 36.2 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 36.2 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 36.2 kB/s eta 0:00:06
#      -------------------------------------- - 6.5/6.7 MB 36.4 kB/s eta 0:00:05
#      -------------------------------------- - 6.5/6.7 MB 36.4 kB/s eta 0:00:05
#      -------------------------------------- - 6.5/6.7 MB 36.4 kB/s eta 0:00:05
#      -------------------------------------- - 6.5/6.7 MB 36.4 kB/s eta 0:00:05
#      -------------------------------------- - 6.5/6.7 MB 36.4 kB/s eta 0:00:05
#      -------------------------------------- - 6.5/6.7 MB 36.4 kB/s eta 0:00:05
#      -------------------------------------- - 6.5/6.7 MB 36.4 kB/s eta 0:00:05
#      -------------------------------------- - 6.5/6.7 MB 36.4 kB/s eta 0:00:05
#      ---------------------------------------  6.6/6.7 MB 36.0 kB/s eta 0:00:05
#      ---------------------------------------  6.6/6.7 MB 36.0 kB/s eta 0:00:05
#      ---------------------------------------  6.6/6.7 MB 36.0 kB/s eta 0:00:05
#      ---------------------------------------  6.6/6.7 MB 36.0 kB/s eta 0:00:05
#      ---------------------------------------  6.6/6.7 MB 36.0 kB/s eta 0:00:05
#      ---------------------------------------  6.6/6.7 MB 36.3 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 36.3 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 36.3 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 36.3 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 36.3 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 36.3 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 36.3 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 36.6 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 36.6 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 36.6 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 36.6 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 37.0 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 37.0 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 37.0 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 37.0 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 37.0 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 37.0 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 37.0 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 37.0 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 37.0 kB/s eta 0:00:04
#      ---------------------------------------  6.6/6.7 MB 36.9 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.9 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.9 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.9 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.9 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.9 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.9 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.9 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.9 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.9 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.9 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.8 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.8 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.8 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.8 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.8 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.8 kB/s eta 0:00:03
#      ---------------------------------------  6.6/6.7 MB 36.8 kB/s eta 0:00:03
#      ---------------------------------------  6.7/6.7 MB 36.8 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 36.8 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 36.8 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 36.8 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 36.8 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 36.8 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 37.2 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 37.2 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 37.2 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 37.2 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 37.2 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 37.2 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 37.2 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 37.2 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 37.2 kB/s eta 0:00:02
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 37.0 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 36.4 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 36.4 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 36.4 kB/s eta 0:00:01
#      ---------------------------------------  6.7/6.7 MB 36.4 kB/s eta 0:00:01
#      ---------------------------------------- 6.7/6.7 MB 36.5 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
# Requirement already satisfied: seaborn==0.11.1 in c:\users\snappmarket\appdata\local\programs\python\python311\lib\site-packages (0.11.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\snappmarket\appdata\local\programs\python\python311\lib\site-packages (from seaborn==0.11.1) (1.24.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\snappmarket\appdata\local\programs\python\python311\lib\site-packages (from seaborn==0.11.1) (1.10.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\snappmarket\appdata\local\programs\python\python311\lib\site-packages (from seaborn==0.11.1) (1.5.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\snappmarket\appdata\local\programs\python\python311\lib\site-packages (from seaborn==0.11.1) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\snappmarket\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.1) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\snappmarket\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\snappmarket\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.1) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\snappmarket\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\snappmarket\appdata\roaming\python\python311\site-packages (from matplotlib>=2.2->seaborn==0.11.1) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\snappmarket\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\snappmarket\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\snappmarket\appdata\roaming\python\python311\site-packages (from matplotlib>=2.2->seaborn==0.11.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\snappmarket\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.23->seaborn==0.11.1) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\snappmarket\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn==0.11.1) (1.16.0)

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# %matplotlib inline

# %%
# also set a random state
rs = 123

# %% [markdown]
# ### Load the user profile dataset

# %% [markdown]
# Let's first load the original user profile feature vectors:

# %%
user_profile_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/datasets/user_profile.csv"
user_profile_df = pd.read_csv(user_profile_url)
user_profile_df.head()
# Out:
#    user  Database  Python  CloudComputing  DataAnalysis  Containers  \
# 0     2      52.0    14.0             6.0          43.0         3.0
# 1     4      40.0     2.0             4.0          28.0         0.0
# 2     5      24.0     8.0            18.0          24.0         0.0
# 3     7       2.0     0.0             0.0           2.0         0.0
# 4     8       6.0     0.0             0.0           4.0         0.0
#
#    MachineLearning  ComputerVision  DataScience  BigData  Chatbot     R  \
# 0             33.0             0.0         29.0     41.0      2.0  18.0
# 1             14.0             0.0         20.0     24.0      0.0   6.0
# 2             30.0             0.0         22.0     14.0      2.0  14.0
# 3              0.0             0.0          0.0      2.0      0.0   0.0
# 4              0.0             0.0          0.0      6.0      0.0   2.0
#
#    BackendDev  FrontendDev  Blockchain
# 0        34.0          9.0         6.0
# 1         6.0          0.0         2.0
# 2        26.0          4.0         6.0
# 3         0.0          0.0         0.0
# 4         0.0          0.0         0.0

# %%
user_profile_df.shape
# Out:
# (33901, 15)

# %% [markdown]
# we can then list the feature names, they are the user interested topics (course genres):

# %%
feature_names = list(user_profile_df.columns[1:])
feature_names
# Out:
# ['Database',
#  'Python',
#  'CloudComputing',
#  'DataAnalysis',
#  'Containers',
#  'MachineLearning',
#  'ComputerVision',
#  'DataScience',
#  'BigData',
#  'Chatbot',
#  'R',
#  'BackendDev',
#  'FrontendDev',
#  'Blockchain']

# %% [markdown]
# As we can see from the user profile dataset, we have about 33K unique users with interests in areas like ``Database``, ``Python``, ``CloudComputing``, etc. Then, let's check the  summary statistics for each feature.

# %%
user_profile_df.describe()
# Out:
#                user      Database        Python  CloudComputing  DataAnalysis  \
# count  3.390100e+04  33901.000000  33901.000000    33901.000000  33901.000000
# mean   1.064064e+06      5.518569      3.493791        2.307100      3.624701
# std    4.972578e+05      7.611941      4.227254        3.841858      4.760135
# min    2.000000e+00      0.000000      0.000000        0.000000      0.000000
# 25%    6.813480e+05      0.000000      0.000000        0.000000      0.000000
# 50%    1.043907e+06      3.000000      3.000000        0.000000      3.000000
# 75%    1.451159e+06      9.000000      6.000000        3.000000      6.000000
# max    2.103039e+06     63.000000     18.000000       38.000000     48.000000
#
#          Containers  MachineLearning  ComputerVision   DataScience  \
# count  33901.000000     33901.000000    33901.000000  33901.000000
# mean       0.998938         3.048022        0.001770      5.087343
# std        2.351764         4.624004        0.072846      5.230697
# min        0.000000         0.000000        0.000000      0.000000
# 25%        0.000000         0.000000        0.000000      0.000000
# 50%        0.000000         0.000000        0.000000      3.000000
# 75%        0.000000         3.000000        0.000000      9.000000
# max       15.000000        39.000000        3.000000     32.000000
#
#             BigData       Chatbot             R    BackendDev   FrontendDev  \
# count  33901.000000  33901.000000  33901.000000  33901.000000  33901.000000
# mean       4.750450      0.462995      1.017433      2.269461      0.315802
# std        7.216228      1.055186      2.342532      4.310752      1.363462
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        2.000000      0.000000      0.000000      0.000000      0.000000
# 75%        6.000000      0.000000      0.000000      3.000000      0.000000
# max       54.000000      6.000000     18.000000     54.000000     15.000000
#
#          Blockchain
# count  33901.000000
# mean       0.986844
# std        1.950585
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        2.000000
# max       12.000000

# %% [markdown]
# The original user profile feature vector is not normalized, which may cause issues when we perform clustering and Principal component analysis (PCA), therefor we standardize the data.

# %%
# Use StandardScaler to make each feature with mean 0, standard deviation 1
scaler = StandardScaler()
user_profile_df[feature_names] = scaler.fit_transform(user_profile_df[feature_names])
print("mean {} and standard deviation{} ".format(user_profile_df[feature_names].mean(),user_profile_df[feature_names].std()))
# Out:
# mean Database          -3.353495e-17
# Python            -5.700942e-17
# CloudComputing    -3.521170e-17
# DataAnalysis      -7.671120e-17
# Containers         3.353495e-18
# MachineLearning    3.688845e-17
# ComputerVision    -1.509073e-17
# DataScience       -1.676748e-17
# BigData            6.706990e-17
# Chatbot           -6.874665e-17
# R                  4.233788e-17
# BackendDev         1.383317e-17
# FrontendDev        5.051202e-17
# Blockchain        -5.281755e-17
# dtype: float64 and standard deviationDatabase           1.000015
# Python             1.000015
# CloudComputing     1.000015
# DataAnalysis       1.000015
# Containers         1.000015
# MachineLearning    1.000015
# ComputerVision     1.000015
# DataScience        1.000015
# BigData            1.000015
# Chatbot            1.000015
# R                  1.000015
# BackendDev         1.000015
# FrontendDev        1.000015
# Blockchain         1.000015
# dtype: float64

# %%
# Use StandardScaler to make each feature with mean 0, standard deviation 1
scaler = StandardScaler()
user_profile_df[feature_names] = scaler.fit_transform(user_profile_df.iloc[:,1:])
print("mean {} and standard deviation{} ".format(user_profile_df[feature_names].mean(),user_profile_df[feature_names].std()))
# Out:
# mean Database          -1.341398e-17
# Python             4.108032e-17
# CloudComputing    -2.137853e-17
# DataAnalysis      -2.263609e-17
# Containers         2.934308e-17
# MachineLearning    5.700942e-17
# ComputerVision    -2.515121e-18
# DataScience       -8.383738e-18
# BigData           -1.676748e-18
# Chatbot           -6.203966e-17
# R                 -4.841609e-17
# BackendDev         1.383317e-17
# FrontendDev        4.673934e-17
# Blockchain        -5.281755e-17
# dtype: float64 and standard deviationDatabase           1.000015
# Python             1.000015
# CloudComputing     1.000015
# DataAnalysis       1.000015
# Containers         1.000015
# MachineLearning    1.000015
# ComputerVision     1.000015
# DataScience        1.000015
# BigData            1.000015
# Chatbot            1.000015
# R                  1.000015
# BackendDev         1.000015
# FrontendDev        1.000015
# Blockchain         1.000015
# dtype: float64

# %%
user_profile_df.describe()
# Out:
#                user      Database        Python  CloudComputing  DataAnalysis  \
# count  3.390100e+04  3.390100e+04  3.390100e+04    3.390100e+04  3.390100e+04
# mean   1.064064e+06 -1.341398e-17  4.108032e-17   -2.137853e-17 -2.263609e-17
# std    4.972578e+05  1.000015e+00  1.000015e+00    1.000015e+00  1.000015e+00
# min    2.000000e+00 -7.249991e-01 -8.265040e-01   -6.005256e-01 -7.614816e-01
# 25%    6.813480e+05 -7.249991e-01 -8.265040e-01   -6.005256e-01 -7.614816e-01
# 50%    1.043907e+06 -3.308757e-01 -1.168130e-01   -6.005256e-01 -1.312380e-01
# 75%    1.451159e+06  4.573712e-01  5.928781e-01    1.803581e-01  4.990056e-01
# max    2.103039e+06  7.551593e+00  3.431642e+00    9.290667e+00  9.322416e+00
#
#          Containers  MachineLearning  ComputerVision   DataScience  \
# count  3.390100e+04     3.390100e+04    3.390100e+04  3.390100e+04
# mean   2.934308e-17     5.700942e-17   -2.515121e-18 -8.383738e-18
# std    1.000015e+00     1.000015e+00    1.000015e+00  1.000015e+00
# min   -4.247674e-01    -6.591835e-01   -2.429612e-02 -9.726080e-01
# 25%   -4.247674e-01    -6.591835e-01   -2.429612e-02 -9.726080e-01
# 50%   -4.247674e-01    -6.591835e-01   -2.429612e-02 -3.990622e-01
# 75%   -4.247674e-01    -1.038556e-02   -2.429612e-02  7.480294e-01
# max    5.953517e+00     7.775190e+00    4.115884e+01  5.145214e+00
#
#             BigData       Chatbot             R    BackendDev   FrontendDev  \
# count  3.390100e+04  3.390100e+04  3.390100e+04  3.390100e+04  3.390100e+04
# mean  -1.676748e-18 -6.203966e-17 -4.841609e-17  1.383317e-17  4.673934e-17
# std    1.000015e+00  1.000015e+00  1.000015e+00  1.000015e+00  1.000015e+00
# min   -6.583107e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 25%   -6.583107e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 50%   -3.811535e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 75%    1.731609e-01 -4.387873e-01 -4.343370e-01  1.694715e-01 -2.316212e-01
# max    6.824934e+00  5.247500e+00  7.249771e+00  1.200053e+01  1.076995e+01
#
#          Blockchain
# count  3.390100e+04
# mean  -5.281755e-17
# std    1.000015e+00
# min   -5.059295e-01
# 25%   -5.059295e-01
# 50%   -5.059295e-01
# 75%    5.194189e-01
# max    5.646161e+00

# %% [markdown]
# The normalized user profile features are:

# %%
features = user_profile_df.loc[:, user_profile_df.columns != 'user']
features
# Out:
#        Database    Python  CloudComputing  DataAnalysis  Containers  \
# 0      6.106474  2.485388        0.961242      8.272010    0.850889
# 1      4.529980 -0.353377        0.440653      5.120792   -0.424767
# 2      2.427988  1.066006        4.084776      4.280467   -0.424767
# 3     -0.462250 -0.826504       -0.600526     -0.341319   -0.424767
# 4      0.063248 -0.826504       -0.600526      0.078843   -0.424767
# ...         ...       ...             ...           ...         ...
# 33896 -0.330876 -0.116813        0.180358      0.499006   -0.424767
# 33897 -0.724999 -0.826504       -0.079936     -0.761482   -0.424767
# 33898 -0.330876  0.592878        0.961242     -0.761482   -0.424767
# 33899 -0.724999 -0.826504       -0.600526     -0.761482   -0.424767
# 33900 -0.724999 -0.826504       -0.600526     -0.761482   -0.424767
#
#        MachineLearning  ComputerVision  DataScience   BigData   Chatbot  \
# 0             6.477594       -0.024296     4.571668  5.023412  1.456642
# 1             2.368540       -0.024296     2.851031  2.667576 -0.438787
# 2             5.828796       -0.024296     3.233395  1.281790  1.456642
# 3            -0.659184       -0.024296    -0.972608 -0.381153 -0.438787
# 4            -0.659184       -0.024296    -0.972608  0.173161 -0.438787
# ...                ...             ...          ...       ...       ...
# 33896        -0.659184       -0.024296     0.174484 -0.658311 -0.438787
# 33897        -0.659184       -0.024296    -0.972608 -0.658311 -0.438787
# 33898         2.368540       -0.024296     0.748029 -0.658311 -0.438787
# 33899        -0.226652       -0.024296    -0.972608 -0.658311 -0.438787
# 33900        -0.226652       -0.024296    -0.972608 -0.658311 -0.438787
#
#               R  BackendDev  FrontendDev  Blockchain
# 0      7.249771    7.360899     6.369323    2.570116
# 1      2.127032    0.865416    -0.231621    0.519419
# 2      5.542191    5.505047     2.702132    2.570116
# 3     -0.434337   -0.526473    -0.231621   -0.505930
# 4      0.419453   -0.526473    -0.231621   -0.505930
# ...         ...         ...          ...         ...
# 33896  2.127032    0.865416    -0.231621    1.032093
# 33897 -0.434337   -0.526473    -0.231621   -0.505930
# 33898  0.846348   -0.526473    -0.231621   -0.505930
# 33899 -0.434337   -0.526473    -0.231621   -0.505930
# 33900 -0.434337   -0.526473    -0.231621   -0.505930
#
# [33901 rows x 14 columns]

# %% [markdown]
# we can also save the user ids for later recommendation tasks:

# %%
user_ids = user_profile_df.loc[:, user_profile_df.columns == 'user']
user_ids
# Out:
#           user
# 0            2
# 1            4
# 2            5
# 3            7
# 4            8
# ...        ...
# 33896  2102054
# 33897  2102356
# 33898  2102680
# 33899  2102983
# 33900  2103039
#
# [33901 rows x 1 columns]

# %% [markdown]
# ### TASK: Perform K-means clustering algorithm on the user profile feature vectors

# %% [markdown]
# With the user profile dataset ready, you need to use the `KMeans` class provided by scikit-learn library to perform clustering on the user profile feature vectors.

# %% [markdown]
# For `KMeans` algorithm, one important hyperparameter is the number of clusters `n_cluster`, and a good way to find the optimized `n_cluster` is using to grid search a list of candidates and find the one with the best or optimized clustering evaluation metrics such as minimal `sum of squared distance`:

# %% [markdown]
# _TODO: grid search the optimized n_cluster for KMeans() model_

# %%
# WRITE YOUR CODE HERE

# Find an optimized number of neighors k from a candidate list such as list_k = list(range(1, 30))

wcss=[]
for i in range(1,30):
    km=KMeans(n_clusters=i)
    km.fit(features)
    wcss.append(km.inertia_)
#The elbow curve
plt.figure(figsize=(12,6))
plt.plot(range(1,30),wcss)
plt.plot(range(1,30),wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("K Value")
plt.xticks(np.arange(1,30,1))
plt.ylabel("WCSS")
plt.show()
# Out:
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# Create a list that will hold the the sum of square distances for each fitted model. For each k in `n_clusters` make a model by calling `KMeans(n_clusters=k, random_state=rs).fit(features)` ans append `model.inertia_` to the list. Plot square distances against the k values.
#
# </details>

# %% [markdown]
# If you plot the grid search process, you may get a elbow plot like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/clusters_elbow.png)

# %% [markdown]
# From the elbow plot, you should visualy identify the point where the metric starting to be flatten, which indicates the optimized number of clusters.

# %% [markdown]
# Once you have identified the best number of clusters, you can apply `KMeans()` again to generate cluster label for all users.

# %%
cluster_labels = [12] * len(user_ids)

# %% [markdown]
# _TODO: Apply KMeans() on the features with optimized n_cluster parameter after model fitting, you can find output cluster labels in `model.labels_` attribute_

# %%
## WRITE YOUR CODE HERE

## ...
## cluster_labels = model.labels
## ...

#Taking clusters
km1=KMeans(n_clusters=12)
#Fitting the input data
km1.fit(features)
#predicting the labels of the input data
y=km1.predict(features)
#adding the labels to a column named label
user_profile_df["label"] = y
#The new dataframe with the clustering done
user_profile_df.head()
# Out:
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#    user  Database    Python  CloudComputing  DataAnalysis  Containers  \
# 0     2  6.106474  2.485388        0.961242      8.272010    0.850889
# 1     4  4.529980 -0.353377        0.440653      5.120792   -0.424767
# 2     5  2.427988  1.066006        4.084776      4.280467   -0.424767
# 3     7 -0.462250 -0.826504       -0.600526     -0.341319   -0.424767
# 4     8  0.063248 -0.826504       -0.600526      0.078843   -0.424767
#
#    MachineLearning  ComputerVision  DataScience   BigData   Chatbot         R  \
# 0         6.477594       -0.024296     4.571668  5.023412  1.456642  7.249771
# 1         2.368540       -0.024296     2.851031  2.667576 -0.438787  2.127032
# 2         5.828796       -0.024296     3.233395  1.281790  1.456642  5.542191
# 3        -0.659184       -0.024296    -0.972608 -0.381153 -0.438787 -0.434337
# 4        -0.659184       -0.024296    -0.972608  0.173161 -0.438787  0.419453
#
#    BackendDev  FrontendDev  Blockchain  label
# 0    7.360899     6.369323    2.570116      2
# 1    0.865416    -0.231621    0.519419      8
# 2    5.505047     2.702132    2.570116      2
# 3   -0.526473    -0.231621   -0.505930      7
# 4   -0.526473    -0.231621   -0.505930      7

# %%
user_profile_df['label'].value_counts()
# Out:
# 7     9193
# 9     4584
# 4     4207
# 10    3409
# 0     3061
# 6     3052
# 1     2806
# 3     1857
# 8      693
# 11     567
# 2      452
# 5       20
# Name: label, dtype: int64

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# Create  a model by calling `KMeans(n_clusters=k, random_state=rs).fit(features)`. Save the labels by accessing `model.labels`.
#
# </details>

# %% [markdown]
# The cluster labels you generated is a list of integers indicating cluster indices. You may use the following utility method to combine the cluster labels and user ids to a dataframe, so that you know which cluster a user belongs:

# %%
def combine_cluster_labels(user_ids, labels):
    labels_df = pd.DataFrame(labels)
    cluster_df = pd.merge(user_ids, labels_df, left_index=True, right_index=True)
    cluster_df.columns = ['user', 'cluster']
    return cluster_df

# %%
combine_cluster_labels(user_profile_df['user'],user_profile_df['label'])
# Out:
#           user  cluster
# 0            2        2
# 1            4        8
# 2            5        2
# 3            7        7
# 4            8        7
# ...        ...      ...
# 33896  2102054        0
# 33897  2102356        7
# 33898  2102680        4
# 33899  2102983        7
# 33900  2103039        7
#
# [33901 rows x 2 columns]

# %% [markdown]
# Your clustering results may look like the following screenshot:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/cluster_labels.png)

# %% [markdown]
# Now, each user finds its own cluster or we can say we have created many clusters of learning communities. Learners within each community share very similar learning interests.

# %% [markdown]
# ### TASK: Apply PCA on user profile feature vectors to reduce dimensions

# %% [markdown]
# In the previous step, we applied `KMeans` on the original user profile feature vectors which have 14 original features (the course genres).

# %%
features = user_profile_df.loc[:, user_profile_df.columns != 'user']
user_ids = user_profile_df.loc[:, user_profile_df.columns == 'user']
feature_names = list(user_profile_df.columns[1:])

# %%
print(f"There are {len(feature_names)} features for each user profile.")
# Out:
# There are 15 features for each user profile.

# %% [markdown]
# If we plot a covariance matrix of the user profile feature vectors with 14 features, we can observe that some features are actually correlated:

# %%
sns.set_theme(style="white")

# Compute the correlation matrix
corr = features.cov()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})


plt.show()

# %% [markdown]
# For example, the feature `MachineLearning` and the feature `DataScience` are correlated. Such covariances among features may indicate that we can apply PCA to find its main components (eigenvectors with max eigenvalues on the covariance matrix).
#
# If we only keep the independent main components, then we can reduce the dimensions of our user profile feature vectors.

# %% [markdown]
# Now let's apply the `PCA()` provided by  `scikit-learn` to find the main components in user profile feature vectors and see if we can reduce its dimensions by only keeping the main components.

# %% [markdown]
# Note that when calling the  `PCA()` class, there is also an import argument called `n_components` which indicates how many components you want to keep in the PCA result. One way to find an optimized `n_components` is to do a grid search on a list of argument candidates (such as `range(1, 15)`) and calculate the ratio of the accumulated variance for each candidate.
#
# If the accumulated variances ratio of a candidate `n_components` is larger than a threshold, e.g., 90%, then we can say the transformed `n_components` could explain about 90% of variances of the original data variance and can be considered as an optimized components size.

# %% [markdown]
# _TODO: Find the optimized `n_components` for PCA_

# %%
# WRITE YOUR CODE HERE

# - For a list of candidate `n_components` arguments such as 1 to 14, find out the minimal `n` that can explain accumulated 90% variances of previous data
# - In the fitted PCA() model, you can find explained_variance_ratio_ and use the sum() function to add them to get the accumulated variance ratio
pca_list = []
for n in range(1,15):
    pca = PCA(n_components = n, random_state=43)
    pca.fit(features)
    pca_df = pca.transform(features)
    pca_list.append(pca.explained_variance_ratio_.sum())

# %%
#pca_list

# %%
plt.bar(x=list(range(1,15)),height=pca_list,width=0.8)
plt.hlines(y=0.9,xmin=0.5,xmax=14.5,color='red')
plt.tight_layout()

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# * For each `n_components` from 1 to 14 you can call `PCA=PCA(n_components=component)`, then you can simply fit it by callsing `pca.fit_transform(features)` where `features = user_profile_df.loc[:, user_profile_df.columns != 'user']`.
# * Then you can find `accumulated_variance_ratios` by applying `sum()` to `pca.explained_variance_ratio_`.
# * Then find the smallest n_components value for which `accumulated_variance_ratios >= 0.9` and return it.
# </details>

# %% [markdown]
# If you visualize your hyperparameter searching process, you may get a trend line like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/pca.png)

# %% [markdown]
# Once you found the optimized `n_component` argument value, you can apply PCA on the user profile feature vectors and reduce the  14 features into  `n_component` features.

# %% [markdown]
# _TODO: Perform PCA to transform original user profile features_

# %%
# WRITE YOUR CODE HERE

# - For a list of candidate `n_components` arguments such as 1 to 14, find out the minimal `n` that can explain accumulated 90% variances of previous data
# - In the fitted PCA() model, you can find explained_variance_ratio_ and use the sum() function to add them to get the accumulated variance ratio
# - Merge the user ids and transformed features into a new dataframe

# %%
pca = PCA(n_components=9, random_state=43)
pca_fit = pca.fit(features)

pca_df = pd.DataFrame(pca_fit.transform(features), columns=["PCA1", "PCA2", "PCA3", "PCA4", "PCA5", "PCA6", "PCA7", 'PCA8', 'PCA9'])
pca_df
# Out:
#            PCA1       PCA2      PCA3      PCA4      PCA5      PCA6      PCA7  \
# 0      5.663997  17.283727  2.164376  1.322053 -1.250081  0.888397  4.105877
# 1     -1.829816   7.799298 -1.143214 -2.185161 -0.008369  0.026749  0.120505
# 2      5.810288  10.384623  1.866755  2.581066 -0.650504  0.158734  1.735425
# 3     -1.592551  -1.570306 -0.069467 -0.424925 -0.004526  0.107433  0.234878
# 4     -1.615519  -0.710222 -0.238227 -0.931225  0.034027  0.069249  0.322355
# ...         ...        ...       ...       ...       ...       ...       ...
# 33896  5.772296  -0.130776 -0.771860 -0.669364 -0.071997  0.211602  1.532872
# 33897 -1.494642  -1.912366  0.180604 -0.155215 -0.056589  0.193048  0.012684
# 33898  1.969617   0.339010 -1.222769  0.970294 -0.422449  0.839174 -0.517683
# 33899 -1.545545  -1.814513 -0.086700 -0.036013 -0.054825  0.181245  0.214945
# 33900 -1.545545  -1.814513 -0.086700 -0.036013 -0.054825  0.181245  0.214945
#
#            PCA8      PCA9
# 0      2.101947  2.795498
# 1      0.586270 -0.419265
# 2      3.198563 -0.534554
# 3      0.022691  0.250429
# 4      0.531706  0.539511
# ...         ...       ...
# 33896  1.753405  0.331807
# 33897  0.198422 -0.014074
# 33898  0.603224 -0.460426
# 33899  0.114410  0.076190
# 33900  0.114410  0.076190
#
# [33901 rows x 9 columns]

# %%
pca_user_df = pd.concat([user_ids['user'], pca_df],  axis = 1)
pca_user_df
# Out:
#           user      PCA1       PCA2      PCA3      PCA4      PCA5      PCA6  \
# 0            2  5.663997  17.283727  2.164376  1.322053 -1.250081  0.888397
# 1            4 -1.829816   7.799298 -1.143214 -2.185161 -0.008369  0.026749
# 2            5  5.810288  10.384623  1.866755  2.581066 -0.650504  0.158734
# 3            7 -1.592551  -1.570306 -0.069467 -0.424925 -0.004526  0.107433
# 4            8 -1.615519  -0.710222 -0.238227 -0.931225  0.034027  0.069249
# ...        ...       ...        ...       ...       ...       ...       ...
# 33896  2102054  5.772296  -0.130776 -0.771860 -0.669364 -0.071997  0.211602
# 33897  2102356 -1.494642  -1.912366  0.180604 -0.155215 -0.056589  0.193048
# 33898  2102680  1.969617   0.339010 -1.222769  0.970294 -0.422449  0.839174
# 33899  2102983 -1.545545  -1.814513 -0.086700 -0.036013 -0.054825  0.181245
# 33900  2103039 -1.545545  -1.814513 -0.086700 -0.036013 -0.054825  0.181245
#
#            PCA7      PCA8      PCA9
# 0      4.105877  2.101947  2.795498
# 1      0.120505  0.586270 -0.419265
# 2      1.735425  3.198563 -0.534554
# 3      0.234878  0.022691  0.250429
# 4      0.322355  0.531706  0.539511
# ...         ...       ...       ...
# 33896  1.532872  1.753405  0.331807
# 33897  0.012684  0.198422 -0.014074
# 33898 -0.517683  0.603224 -0.460426
# 33899  0.214945  0.114410  0.076190
# 33900  0.214945  0.114410  0.076190
#
# [33901 rows x 10 columns]

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# * Call PCA class as `pca = PCA(n_components=n_components)`
# * Fit PCA model using predefined `features` variable as only parameter
# * Get the components by calling `pca.fit_transform(features)`
# * Create a `pd.DataFrame(data=components)` and use `pd.merge` to merge it with `user_ids` don't forget to specify `left_index=True, right_index=True` in `merge` function parameters.
#
# </details>

# %% [markdown]
# Your PCA transformed dataframe may look like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/pca_res.png)

# %% [markdown]
# ### TASK: Perform k-means clustering on the PCA transformed feature vectors

# %% [markdown]
# Now, you have the PCA  components of the original profile vectors. You can perform k-means on them again:

# %% [markdown]
# _TODO: Perform K-means on the PCA transformed features_

# %%
## WRITE YOUR CODE HERE

## - Apply KMeans() on the PCA features
## - Obtain the cluster label lists from model.labels_ attribute
## - Assign each user a cluster label by combining user ids and cluster labels

# WRITE YOUR CODE HERE

wcss=[]
for i in range(1,30):
    km=KMeans(n_clusters=i)
    km.fit(pca_df)
    wcss.append(km.inertia_)
#The elbow curve
plt.figure(figsize=(12,6))
plt.plot(range(1,30),wcss)
plt.plot(range(1,30),wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("K Value")
plt.xticks(np.arange(1,30,1))
plt.ylabel("WCSS")
plt.show()
# Out:
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
## WRITE YOUR CODE HERE

## ...
## cluster_labels = model.labels
## ...

#Taking clusters
km1=KMeans(n_clusters=18)
#Fitting the input data
km1.fit(pca_df)
#predicting the labels of the input data
y=km1.predict(pca_df)
#adding the labels to a column named label
pca_user_df["label"] = y
#The new dataframe with the clustering done
pca_user_df.head()
# Out:
# c:\Users\SnappMarket\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#    user      PCA1       PCA2      PCA3      PCA4      PCA5      PCA6  \
# 0     2  5.663997  17.283727  2.164376  1.322053 -1.250081  0.888397
# 1     4 -1.829816   7.799298 -1.143214 -2.185161 -0.008369  0.026749
# 2     5  5.810288  10.384623  1.866755  2.581066 -0.650504  0.158734
# 3     7 -1.592551  -1.570306 -0.069467 -0.424925 -0.004526  0.107433
# 4     8 -1.615519  -0.710222 -0.238227 -0.931225  0.034027  0.069249
#
#        PCA7      PCA8      PCA9  label
# 0  4.105877  2.101947  2.795498     11
# 1  0.120505  0.586270 -0.419265      6
# 2  1.735425  3.198563 -0.534554     11
# 3  0.234878  0.022691  0.250429      0
# 4  0.322355  0.531706  0.539511      0

# %%
combine_cluster_labels(pca_user_df['user'],pca_user_df['label'])
# Out:
#           user  cluster
# 0            2       11
# 1            4        6
# 2            5       11
# 3            7        0
# 4            8        0
# ...        ...      ...
# 33896  2102054       12
# 33897  2102356        0
# 33898  2102680        2
# 33899  2102983        0
# 33900  2103039        0
#
# [33901 rows x 2 columns]

# %% [markdown]
# Your clustering results should have the same format as the k-means on the original dataset:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/cluster_labels.png)

# %% [markdown]
# Great, now all users find their learning interest groups, either based on their original or the PCA transformed user profile features.

# %% [markdown]
# When a user is in a group or a community, it is very likely that the user will be interested in the courses enrolled by other members within the same group.

# %% [markdown]
# ### TASK: Generate course recommendations based on the popular courses in the same cluster

# %% [markdown]
# The Intuition of clustering-based course recommendation is very simple and can be illustrated via the following example:

# %% [markdown]
# Suppose a user has joined a machine learning group (via clustering algorithm). In the group, he/she finds that the top-3 courses enrolled by all other group members are `Machine Learning for Everyone`, `Machine Learning with Python`, `Machine Learning with Scikit-learn`. Since the user has already completed the `Machine Learning for Everyone` earlier, he/she decides to trust the group members' choices and enroll in other two unselected courses `Machine Learning with Python` and `Machine Learning with Scikit-learn`.

# %% [markdown]
# In summary, the clustering-based recommender system first groups all users based on their profiles, and maintains a popular courses list for each group.
#
# For any group member who needs course recommendations, the algorithm recommends the unselected courses from the popular course lists.

# %% [markdown]
# Next, suppose we have a set of test users, and we want to recommend new courses to them using a clustering-based recommender system:

# %%
test_user_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/datasets/rs_content_test.csv"
test_users_df = pd.read_csv(test_user_url)[['user', 'item']]
test_users_df.head()
# Out:
#       user      item
# 0  1502801  RP0105EN
# 1  1609720  CNSC02EN
# 2  1347188  CO0301EN
# 3   755067  ML0103EN
# 4   538595  BD0115EN

# %% [markdown]
# The test users dataset has only two columns, the user id and the enrolled course id.

# %% [markdown]
# For each user, let's find its cluster label using the k-means results you have performed in previous steps, assuming it is named `cluster_df`.

# %% [markdown]
# You can assign the cluster label to all test users via merging the clustering labels (`cluster_df`:):

# %%
# test_users_labelled = pd.merge(test_users_df, cluster_df, left_on='user', right_on='user')
cluster_df = test_users_df.merge(pca_user_df[['user','label']], on= 'user', how = 'inner')

# %%
cluster_df.rename(columns={'label':'cluster'}, inplace=True)

# %%
cluster_df
# Out:
#          user      item  cluster
# 0     1502801  RP0105EN        3
# 1     1502801  BD0131EN        3
# 2     1502801  BD0212EN        3
# 3     1502801  BD0115EN        3
# 4     1502801  BD0211EN        3
# ...       ...       ...      ...
# 9397   630511  BD0121EN       13
# 9398   630511  SC0101EN       13
# 9399   630511  BD0111EN       13
# 9400   630511  BD0115EN       13
# 9401   630511  PY0101EN       13
#
# [9402 rows x 3 columns]

# %% [markdown]
# The merged the test dataset may look like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/test_users_label.png)

# %% [markdown]
# From the above dataframe, we know each user's enrolled courses and its cluster index.

# %% [markdown]
# If we use a `groupby`  and `sum` aggregation, we can get the enrollments count for each course in each group, like the following code snippet:

# %%
'''
courses_cluster = test_users_labelled[['item', 'cluster']]
courses_cluster['count'] = [1] * len(courses_cluster)
courses_cluster.groupby(['cluster','item']).agg(enrollments = ('count','sum')).reset_index()
'''
courses_cluster = cluster_df[['item', 'cluster']]
courses_cluster['count'] = [1] * len(courses_cluster)
courses_cluster_group = courses_cluster.groupby(['cluster','item']).agg(enrollments = ('count','sum')).reset_index()
courses_cluster_group
# Out:
#       cluster      item  enrollments
# 0           0  AI0111EN            1
# 1           0  BC0101EN           30
# 2           0  BC0201EN           17
# 3           0  BC0202EN            3
# 4           0  BD0101EN           58
# ...       ...       ...          ...
# 1122       17  SW0201EN            2
# 1123       17    TA0105            1
# 1124       17  TA0105EN            5
# 1125       17  TA0106EN            1
# 1126       17  WA0101EN            2
#
# [1127 rows x 3 columns]

# %%
courses_cluster_group.describe()
# Out:
#            cluster  enrollments
# count  1127.000000  1127.000000
# mean      8.343390     8.342502
# std       5.554678    13.279205
# min       0.000000     1.000000
# 25%       3.000000     1.000000
# 50%       9.000000     3.000000
# 75%      13.000000     9.000000
# max      17.000000   134.000000

# %% [markdown]
# _TODO: For each test user, try to recommend any unseen courses based on the popular courses in his/her cluster. You may use an enrollment count threshold (such as larger than 10) to determine if it is a popular course in the cluster_

# %%
## WRITE YOUR CODE HERE

## - For each user, first finds its cluster label

    ## - First get all courses belonging to the same cluster and figure out what are the popular ones (such as course enrollments beyond a threshold like 100)
    
    ## - Get the user's current enrolled courses
    
    ## - Check if there are any courses on the popular course list which are new/unseen to the user. 
    
    ## If yes, make those unseen and popular courses as recommendation results for the user

courses_cluster_group_pop = courses_cluster_group[courses_cluster_group['enrollments']>=50]
courses_cluster_group_pop
# Out:
#       cluster        item  enrollments
# 4           0    BD0101EN           58
# 46          0    DS0101EN           63
# 83          0    PY0101EN           51
# 114         1    CC0101EN           56
# 117         1    CC0201EN           50
# 123         1    CO0101EN           71
# 124         1    CO0201EN           58
# 196         2    DA0101EN          119
# 202         2    DS0101EN           72
# 209         2    DV0101EN          103
# 216         2  ML0101ENv3           95
# 220         2    ML0115EN           66
# 230         2    PY0101EN          134
# 535         7    RP0101EN           52
# 728        12    BC0101EN           57
# 798        13    BD0101EN           63
# 822        13    DS0101EN           76
# 843        13    PY0101EN           67
# 919        15    BD0101EN           86
# 920        15    BD0111EN           94
# 921        15    BD0115EN           58
# 933        15    BD0211EN           85
# 1001       16    CB0103EN           50

# %%
courses_cluster_group.groupby(['cluster','item'])['enrollments'].max().reset_index()
# Out:
#       cluster      item  enrollments
# 0           0  AI0111EN            1
# 1           0  BC0101EN           30
# 2           0  BC0201EN           17
# 3           0  BC0202EN            3
# 4           0  BD0101EN           58
# ...       ...       ...          ...
# 1122       17  SW0201EN            2
# 1123       17    TA0105            1
# 1124       17  TA0105EN            5
# 1125       17  TA0106EN            1
# 1126       17  WA0101EN            2
#
# [1127 rows x 3 columns]

# %%
cluster_df_user = cluster_df[cluster_df['cluster'].isin(courses_cluster_group_pop['cluster'])]
cluster_df_user['cluster'].value_counts()
# Out:
# 0     1319
# 2     1174
# 15     789
# 7      771
# 1      735
# 13     597
# 16     483
# 12     452
# Name: cluster, dtype: int64

# %%
courses_cluster = cluster_df_user[['item', 'cluster']]
cluster_df_user['count'] = [1] * len(courses_cluster)
user_enroll = cluster_df_user.groupby(['cluster','item']).agg(enrollments = ('count','sum')).reset_index()
user_enroll
# Out:
# C:\Users\SnappMarket\AppData\Local\Temp\ipykernel_13172\3734825936.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster_df_user['count'] = [1] * len(courses_cluster)
#      cluster      item  enrollments
# 0          0  AI0111EN            1
# 1          0  BC0101EN           30
# 2          0  BC0201EN           17
# 3          0  BC0202EN            3
# 4          0  BD0101EN           58
# ..       ...       ...          ...
# 568       16  ST0101EN           10
# 569       16  SW0201EN            1
# 570       16    TA0105            2
# 571       16  TA0105EN            4
# 572       16  WA0101EN            6
#
# [573 rows x 3 columns]

# %%
course_unique = courses_cluster_group_pop['item'].unique

# %%
cluster_dict = {}
for index, row in cluster_df_user.iterrows():
    if row['item'] in course_unique():
        if row['user'] in cluster_dict:
            cluster_dict[row['user']].append(row['item'])
        else:
            cluster_dict[row['user']] = [row['item']]

# %%
cluster_dict
# Out:
# {1609720: ['ML0101ENv3', 'DS0101EN', 'DV0101EN', 'DA0101EN'],
#  1347188: ['CO0201EN', 'PY0101EN', 'BC0101EN'],
#  755067: ['BD0101EN'],
#  538595: ['BD0115EN', 'BD0111EN', 'BD0101EN'],
#  1773079: ['CC0201EN', 'CC0101EN'],
#  603361: ['CO0101EN', 'BD0101EN', 'CO0201EN'],
#  1122903: ['RP0101EN',
#   'ML0115EN',
#   'BD0211EN',
#   'CO0201EN',
#   'BD0115EN',
#   'BD0111EN',
#   'PY0101EN',
#   'DV0101EN',
#   'BC0101EN',
#   'DA0101EN',
#   'CO0101EN',
#   'BD0101EN'],
#  881847: ['DV0101EN',
#   'BD0111EN',
#   'PY0101EN',
#   'ML0115EN',
#   'DA0101EN',
#   'CB0103EN',
#   'RP0101EN',
#   'BD0211EN'],
#  1221910: ['DS0101EN', 'BD0101EN', 'BC0101EN', 'CO0101EN', 'DA0101EN'],
#  1636610: ['PY0101EN', 'DS0101EN', 'BC0101EN', 'ML0101ENv3'],
#  1504635: ['BD0101EN', 'DS0101EN', 'CO0101EN', 'CC0101EN'],
#  462755: ['PY0101EN',
#   'ML0101ENv3',
#   'DS0101EN',
#   'ML0115EN',
#   'BD0211EN',
#   'DV0101EN',
#   'BD0101EN',
#   'DA0101EN',
#   'RP0101EN'],
#  902138: ['BD0211EN', 'BD0111EN', 'BD0101EN', 'BD0115EN', 'PY0101EN'],
#  1102170: ['BD0101EN', 'CO0101EN', 'BC0101EN', 'CC0201EN'],
#  510780: ['BD0101EN',
#   'DS0101EN',
#   'RP0101EN',
#   'BD0211EN',
#   'BD0115EN',
#   'BD0111EN'],
#  704521: ['ML0101ENv3',
#   'CB0103EN',
#   'DS0101EN',
#   'ML0115EN',
#   'RP0101EN',
#   'PY0101EN',
#   'BC0101EN',
#   'DA0101EN',
#   'DV0101EN'],
#  517197: ['PY0101EN',
#   'CB0103EN',
#   'CO0101EN',
#   'BD0211EN',
#   'RP0101EN',
#   'BD0101EN',
#   'BD0111EN',
#   'DV0101EN',
#   'DA0101EN',
#   'DS0101EN',
#   'BD0115EN'],
#  1806207: ['BD0101EN', 'PY0101EN', 'BD0111EN', 'CC0101EN', 'DS0101EN'],
#  1648099: ['DS0101EN', 'ML0115EN', 'BC0101EN', 'CC0101EN', 'CO0101EN'],
#  108541: ['PY0101EN', 'BD0111EN', 'BD0115EN', 'BD0101EN', 'BD0211EN'],
#  1642918: ['PY0101EN',
#   'RP0101EN',
#   'DS0101EN',
#   'ML0101ENv3',
#   'DV0101EN',
#   'DA0101EN'],
#  601371: ['BD0211EN', 'RP0101EN'],
#  1199884: ['DS0101EN', 'PY0101EN', 'RP0101EN', 'BD0101EN'],
#  708518: ['BD0111EN',
#   'ML0115EN',
#   'DV0101EN',
#   'DA0101EN',
#   'ML0101ENv3',
#   'DS0101EN',
#   'PY0101EN',
#   'BD0101EN',
#   'RP0101EN'],
#  1351020: ['CO0101EN', 'ML0101ENv3', 'PY0101EN', 'ML0115EN', 'BD0111EN'],
#  472908: ['RP0101EN', 'BD0101EN', 'BD0111EN'],
#  1541383: ['CO0101EN',
#   'DA0101EN',
#   'PY0101EN',
#   'ML0101ENv3',
#   'ML0115EN',
#   'DV0101EN'],
#  877026: ['DS0101EN', 'BD0101EN'],
#  755044: ['ML0115EN', 'BD0211EN', 'BD0101EN', 'DA0101EN', 'BD0111EN'],
#  913275: ['BD0211EN', 'BD0111EN', 'BD0115EN'],
#  1275452: ['BD0101EN',
#   'CC0201EN',
#   'BD0115EN',
#   'DV0101EN',
#   'PY0101EN',
#   'CB0103EN',
#   'CO0101EN',
#   'ML0101ENv3',
#   'ML0115EN',
#   'DA0101EN'],
#  985429: ['BD0111EN',
#   'PY0101EN',
#   'BD0211EN',
#   'DA0101EN',
#   'BD0101EN',
#   'DV0101EN',
#   'DS0101EN'],
#  1237626: ['BD0101EN', 'DS0101EN', 'ML0115EN', 'PY0101EN'],
#  577001: ['BD0211EN', 'RP0101EN', 'DS0101EN', 'BD0101EN', 'ML0115EN'],
#  981848: ['DV0101EN',
#   'ML0115EN',
#   'PY0101EN',
#   'RP0101EN',
#   'DS0101EN',
#   'BD0101EN',
#   'DA0101EN'],
#  1751931: ['ML0101ENv3', 'CB0103EN', 'DA0101EN', 'ML0115EN', 'PY0101EN'],
#  1378699: ['CC0101EN', 'PY0101EN', 'ML0101ENv3'],
#  705065: ['BC0101EN',
#   'DA0101EN',
#   'DS0101EN',
#   'DV0101EN',
#   'CO0201EN',
#   'PY0101EN'],
#  1452505: ['CO0101EN', 'CO0201EN', 'PY0101EN', 'BD0101EN'],
#  762860: ['DV0101EN',
#   'BD0115EN',
#   'BD0111EN',
#   'PY0101EN',
#   'BD0211EN',
#   'DA0101EN',
#   'DS0101EN'],
#  1571271: ['RP0101EN',
#   'PY0101EN',
#   'CB0103EN',
#   'ML0101ENv3',
#   'DA0101EN',
#   'DV0101EN'],
#  1194679: ['BD0115EN', 'BD0211EN', 'BD0111EN'],
#  1882084: ['BD0111EN',
#   'BD0101EN',
#   'RP0101EN',
#   'PY0101EN',
#   'DV0101EN',
#   'DS0101EN',
#   'BD0211EN'],
#  569052: ['DS0101EN', 'BD0101EN', 'BD0111EN', 'BD0211EN'],
#  1316258: ['DV0101EN',
#   'ML0101ENv3',
#   'CO0201EN',
#   'DA0101EN',
#   'PY0101EN',
#   'CC0101EN',
#   'CO0101EN'],
#  1016747: ['BD0211EN', 'BD0115EN', 'DS0101EN', 'BD0111EN', 'BD0101EN'],
#  494226: ['BD0211EN', 'BD0111EN', 'BD0101EN'],
#  699465: ['BD0101EN', 'BD0111EN', 'BD0211EN', 'DS0101EN'],
#  886106: ['BD0101EN',
#   'BD0111EN',
#   'CC0201EN',
#   'PY0101EN',
#   'CC0101EN',
#   'DA0101EN',
#   'DV0101EN',
#   'RP0101EN',
#   'DS0101EN'],
#  740210: ['BD0101EN', 'BD0115EN', 'BD0111EN', 'BD0211EN'],
#  690872: ['DS0101EN', 'BD0101EN', 'ML0115EN', 'PY0101EN', 'BD0111EN'],
#  705746: ['CO0101EN',
#   'BD0101EN',
#   'BC0101EN',
#   'PY0101EN',
#   'DV0101EN',
#   'BD0211EN',
#   'CC0201EN',
#   'CO0201EN',
#   'DS0101EN',
#   'BD0111EN',
#   'CB0103EN',
#   'DA0101EN',
#   'ML0115EN'],
#  759038: ['BD0111EN',
#   'BC0101EN',
#   'BD0115EN',
#   'BD0211EN',
#   'PY0101EN',
#   'DS0101EN',
#   'RP0101EN'],
#  1212187: ['DS0101EN',
#   'DV0101EN',
#   'DA0101EN',
#   'ML0115EN',
#   'PY0101EN',
#   'ML0101ENv3'],
#  1715864: ['DA0101EN',
#   'BD0101EN',
#   'CC0101EN',
#   'PY0101EN',
#   'DV0101EN',
#   'DS0101EN'],
#  738131: ['BD0111EN', 'PY0101EN', 'BD0211EN', 'DV0101EN', 'DA0101EN'],
#  1271375: ['CC0101EN', 'CO0201EN', 'CC0201EN', 'CO0101EN', 'ML0101ENv3'],
#  1405594: ['BD0101EN', 'CC0101EN', 'BC0101EN', 'CO0101EN', 'PY0101EN'],
#  266643: ['BD0211EN',
#   'DS0101EN',
#   'RP0101EN',
#   'BD0111EN',
#   'CO0201EN',
#   'BD0101EN',
#   'PY0101EN',
#   'CO0101EN',
#   'CC0101EN'],
#  1194262: ['CO0101EN', 'PY0101EN', 'CO0201EN'],
#  1538828: ['BD0111EN',
#   'DA0101EN',
#   'PY0101EN',
#   'ML0101ENv3',
#   'RP0101EN',
#   'BC0101EN',
#   'BD0101EN',
#   'DS0101EN'],
#  669512: ['BD0111EN',
#   'ML0115EN',
#   'BD0211EN',
#   'CO0101EN',
#   'CO0201EN',
#   'DS0101EN',
#   'RP0101EN',
#   'BD0101EN',
#   'PY0101EN'],
#  1287782: ['CO0101EN', 'PY0101EN', 'CO0201EN', 'DA0101EN', 'DV0101EN'],
#  1006163: ['ML0101ENv3',
#   'BD0111EN',
#   'PY0101EN',
#   'DS0101EN',
#   'DA0101EN',
#   'BD0101EN'],
#  2021696: ['DV0101EN', 'DA0101EN', 'PY0101EN', 'ML0101ENv3', 'ML0115EN'],
#  1596323: ['CC0101EN', 'CO0101EN'],
#  979847: ['DV0101EN', 'PY0101EN', 'DS0101EN', 'DA0101EN', 'ML0101ENv3'],
#  998607: ['BD0101EN', 'BC0101EN', 'BD0211EN', 'DS0101EN', 'BD0111EN'],
#  1521903: ['PY0101EN', 'CC0101EN'],
#  1404598: ['CB0103EN',
#   'DA0101EN',
#   'BD0111EN',
#   'DV0101EN',
#   'BC0101EN',
#   'DS0101EN',
#   'ML0115EN',
#   'ML0101ENv3',
#   'PY0101EN'],
#  887336: ['ML0115EN', 'PY0101EN', 'DV0101EN', 'DA0101EN'],
#  1206954: ['BD0211EN', 'DS0101EN', 'BD0101EN', 'PY0101EN', 'DA0101EN'],
#  1783867: ['ML0101ENv3',
#   'PY0101EN',
#   'CB0103EN',
#   'DA0101EN',
#   'DV0101EN',
#   'RP0101EN',
#   'DS0101EN',
#   'BD0101EN'],
#  1224751: ['CO0101EN', 'BD0101EN', 'CC0101EN', 'CO0201EN'],
#  1444838: ['CO0101EN',
#   'PY0101EN',
#   'CC0101EN',
#   'BD0211EN',
#   'BD0111EN',
#   'BD0101EN'],
#  560247: ['BD0101EN', 'BD0111EN'],
#  2004142: ['DS0101EN', 'DA0101EN'],
#  1078030: ['DA0101EN', 'DV0101EN', 'ML0115EN', 'ML0101ENv3', 'PY0101EN'],
#  621543: ['BC0101EN', 'BD0101EN', 'ML0115EN', 'BD0111EN'],
#  152320: ['BD0111EN', 'BD0211EN'],
#  578677: ['BD0211EN',
#   'PY0101EN',
#   'BC0101EN',
#   'BD0111EN',
#   'CO0101EN',
#   'BD0101EN',
#   'DS0101EN'],
#  2022708: ['DV0101EN', 'DA0101EN', 'PY0101EN', 'ML0101ENv3', 'ML0115EN'],
#  1215047: ['BD0101EN', 'RP0101EN', 'DS0101EN'],
#  1313360: ['BD0101EN', 'DS0101EN', 'BD0211EN', 'BD0111EN', 'BD0115EN'],
#  1458003: ['ML0101ENv3',
#   'DA0101EN',
#   'DV0101EN',
#   'BD0115EN',
#   'CB0103EN',
#   'ML0115EN',
#   'PY0101EN',
#   'BD0101EN'],
#  627837: ['DV0101EN',
#   'DS0101EN',
#   'DA0101EN',
#   'PY0101EN',
#   'BD0101EN',
#   'RP0101EN',
#   'BD0111EN'],
#  1736248: ['DA0101EN',
#   'ML0101ENv3',
#   'RP0101EN',
#   'DV0101EN',
#   'BD0101EN',
#   'PY0101EN',
#   'DS0101EN',
#   'BD0111EN'],
#  1391909: ['BD0211EN', 'CO0201EN', 'ML0115EN', 'ML0101ENv3', 'PY0101EN'],
#  1571241: ['ML0115EN', 'DA0101EN', 'PY0101EN', 'DS0101EN', 'DV0101EN'],
#  1730632: ['ML0101ENv3', 'CC0201EN', 'CC0101EN'],
#  753875: ['ML0115EN',
#   'CB0103EN',
#   'BD0101EN',
#   'DA0101EN',
#   'DS0101EN',
#   'DV0101EN'],
#  1559681: ['RP0101EN', 'PY0101EN', 'BC0101EN', 'DS0101EN'],
#  1831769: ['CC0101EN', 'CC0201EN', 'CO0101EN'],
#  1457700: ['CC0101EN', 'CO0101EN', 'CC0201EN'],
#  1284176: ['CO0201EN', 'CO0101EN', 'CC0101EN', 'DS0101EN', 'PY0101EN'],
#  1230771: ['CO0201EN', 'CO0101EN'],
#  1273446: ['BD0211EN', 'ML0101ENv3'],
#  1073082: ['BD0101EN', 'BD0115EN', 'BD0211EN', 'BD0111EN', 'PY0101EN'],
#  1964245: ['CC0201EN', 'RP0101EN', 'PY0101EN', 'CC0101EN'],
#  1345617: ['CO0101EN',
#   'DA0101EN',
#   'PY0101EN',
#   'BD0101EN',
#   'ML0101ENv3',
#   'DS0101EN',
#   'DV0101EN',
#   'BD0111EN'],
#  1436224: ['BD0101EN',
#   'PY0101EN',
#   'BD0111EN',
#   'CO0201EN',
#   'BC0101EN',
#   'BD0211EN',
#   'ML0101ENv3',
#   'CO0101EN'],
#  1916547: ['PY0101EN',
#   'ML0115EN',
#   'ML0101ENv3',
#   'DS0101EN',
#   'DA0101EN',
#   'DV0101EN'],
#  968795: ['BD0211EN', 'PY0101EN'],
#  1208537: ['BC0101EN',
#   'DA0101EN',
#   'DS0101EN',
#   'DV0101EN',
#   'ML0101ENv3',
#   'ML0115EN',
#   'BD0101EN',
#   'PY0101EN'],
#  696942: ['BD0115EN', 'BD0101EN', 'BD0111EN'],
#  419414: ['ML0101ENv3', 'DA0101EN', 'DV0101EN', 'CB0103EN'],
#  646160: ['ML0101ENv3',
#   'RP0101EN',
#   'PY0101EN',
#   'DS0101EN',
#   'BD0111EN',
#   'BD0101EN'],
#  1688652: ['BD0111EN', 'BD0115EN'],
#  1019556: ['BC0101EN',
#   'DS0101EN',
#   'BD0101EN',
#   'CO0101EN',
#   'ML0115EN',
#   'PY0101EN',
#   'BD0111EN',
#   'CO0201EN'],
#  1027344: ['BD0101EN',
#   'CO0201EN',
#   'BD0111EN',
#   'BD0211EN',
#   'DS0101EN',
#   'CO0101EN'],
#  1593639: ['BC0101EN', 'CO0101EN', 'PY0101EN'],
#  1819037: ['ML0115EN', 'PY0101EN', 'ML0101ENv3', 'BD0101EN', 'DA0101EN'],
#  957960: ['DS0101EN', 'BD0111EN', 'BC0101EN'],
#  1107112: ['CO0201EN',
#   'BD0211EN',
#   'BD0111EN',
#   'BD0101EN',
#   'BC0101EN',
#   'CO0101EN',
#   'ML0101ENv3'],
#  1014699: ['CO0101EN', 'CC0101EN', 'CC0201EN', 'DS0101EN', 'CO0201EN'],
#  2046621: ['PY0101EN', 'ML0101ENv3', 'DA0101EN', 'DV0101EN'],
#  485273: ['BD0111EN', 'BD0115EN', 'BD0211EN', 'DS0101EN', 'BD0101EN'],
#  1806813: ['BD0101EN', 'DS0101EN', 'DA0101EN', 'PY0101EN', 'DV0101EN'],
#  1573190: ['ML0115EN', 'DV0101EN', 'ML0101ENv3'],
#  1886079: ['DV0101EN',
#   'ML0115EN',
#   'DS0101EN',
#   'ML0101ENv3',
#   'DA0101EN',
#   'PY0101EN'],
#  750640: ['BD0101EN', 'DA0101EN', 'BD0111EN', 'PY0101EN'],
#  296101: ['DS0101EN',
#   'BD0211EN',
#   'CO0101EN',
#   'BD0101EN',
#   'BD0111EN',
#   'BD0115EN',
#   'PY0101EN'],
#  886688: ['DA0101EN',
#   'DV0101EN',
#   'BC0101EN',
#   'PY0101EN',
#   'ML0115EN',
#   'RP0101EN'],
#  948812: ['BD0111EN', 'BD0211EN', 'DS0101EN', 'CO0201EN', 'BC0101EN'],
#  1188137: ['DS0101EN', 'BD0101EN'],
#  883150: ['PY0101EN', 'BD0101EN', 'DS0101EN'],
#  973663: ['CB0103EN', 'PY0101EN', 'BD0115EN', 'BD0101EN', 'ML0115EN'],
#  988115: ['RP0101EN',
#   'ML0101ENv3',
#   'BC0101EN',
#   'PY0101EN',
#   'BD0101EN',
#   'DV0101EN',
#   'DS0101EN',
#   'BD0211EN',
#   'DA0101EN',
#   'BD0111EN'],
#  1304909: ['PY0101EN', 'CO0201EN', 'ML0101ENv3', 'CO0101EN', 'CC0101EN'],
#  142685: ['BD0211EN',
#   'DA0101EN',
#   'BC0101EN',
#   'PY0101EN',
#   'DV0101EN',
#   'ML0115EN'],
#  182509: ['BD0211EN',
#   'ML0115EN',
#   'CC0101EN',
#   'DS0101EN',
#   'ML0101ENv3',
#   'BD0101EN',
#   'BC0101EN',
#   'DA0101EN',
#   'PY0101EN',
#   'BD0111EN'],
#  1167829: ['BC0101EN', 'BD0101EN', 'PY0101EN', 'CO0101EN'],
#  480186: ['DA0101EN', 'BD0101EN', 'BD0111EN', 'BD0211EN'],
#  1291244: ['RP0101EN',
#   'CO0201EN',
#   'BD0111EN',
#   'DA0101EN',
#   'BC0101EN',
#   'BD0211EN',
#   'ML0101ENv3',
#   'CC0101EN',
#   'DV0101EN',
#   'PY0101EN',
#   'DS0101EN',
#   'ML0115EN',
#   'BD0101EN'],
#  1619917: ['DV0101EN',
#   'DA0101EN',
#   'RP0101EN',
#   'PY0101EN',
#   'CB0103EN',
#   'DS0101EN'],
#  628701: ['BD0111EN',
#   'BD0211EN',
#   'DS0101EN',
#   'CB0103EN',
#   'CC0101EN',
#   'CC0201EN',
#   'BD0101EN'],
#  1296757: ['BC0101EN', 'DS0101EN', 'RP0101EN'],
#  897866: ['BD0115EN', 'BD0101EN', 'BD0111EN'],
#  1691129: ['RP0101EN',
#   'DV0101EN',
#   'BC0101EN',
#   'ML0101ENv3',
#   'DA0101EN',
#   'BD0101EN',
#   'CC0101EN',
#   'DS0101EN',
#   'PY0101EN'],
#  1607405: ['ML0101ENv3',
#   'DA0101EN',
#   'BD0101EN',
#   'PY0101EN',
#   'DS0101EN',
#   'BD0111EN'],
#  1251998: ['CO0201EN', 'ML0101ENv3', 'CO0101EN'],
#  1813726: ['DS0101EN', 'PY0101EN', 'BD0101EN'],
#  1697791: ['DV0101EN',
#   'DA0101EN',
#   'CC0101EN',
#   'CB0103EN',
#   'ML0101ENv3',
#   'PY0101EN'],
#  1121817: ['CC0101EN',
#   'DA0101EN',
#   'BC0101EN',
#   'BD0101EN',
#   'PY0101EN',
#   'DV0101EN'],
#  940704: ['DS0101EN',
#   'DA0101EN',
#   'DV0101EN',
#   'CB0103EN',
#   'PY0101EN',
#   'ML0115EN',
#   'RP0101EN'],
#  931463: ['DA0101EN', 'PY0101EN', 'ML0115EN', 'BD0211EN'],
#  1180992: ['PY0101EN', 'BC0101EN', 'DS0101EN'],
#  1831780: ['DS0101EN', 'PY0101EN'],
#  702927: ['BD0101EN',
#   'ML0115EN',
#   'DV0101EN',
#   'DA0101EN',
#   'BD0211EN',
#   'PY0101EN'],
#  1438699: ['DV0101EN', 'RP0101EN', 'PY0101EN'],
#  1893628: ['DV0101EN',
#   'ML0115EN',
#   'DA0101EN',
#   'DS0101EN',
#   'PY0101EN',
#   'ML0101ENv3'],
#  699014: ['BD0211EN', 'BD0111EN', 'BD0101EN'],
#  1608895: ['BD0101EN', 'DV0101EN', 'ML0101ENv3', 'PY0101EN'],
#  968280: ['DS0101EN', 'ML0115EN'],
#  2057052: ['DS0101EN', 'ML0101ENv3', 'PY0101EN'],
#  435051: ['BD0101EN', 'BD0211EN', 'BD0111EN', 'BD0115EN', 'DS0101EN'],
#  1300715: ['BD0101EN', 'BC0101EN'],
#  515823: ['BD0111EN', 'BD0101EN', 'BD0211EN'],
#  1382697: ['CO0201EN', 'ML0101ENv3', 'CO0101EN', 'CC0201EN'],
#  1008779: ['DS0101EN', 'CO0101EN', 'PY0101EN', 'DA0101EN', 'DV0101EN'],
#  1167173: ['PY0101EN', 'BD0101EN', 'DA0101EN'],
#  243266: ['ML0115EN',
#   'DS0101EN',
#   'DA0101EN',
#   'CB0103EN',
#   'PY0101EN',
#   'RP0101EN'],
#  503032: ['BD0211EN',
#   'BD0115EN',
#   'DS0101EN',
#   'BD0101EN',
#   'RP0101EN',
#   'BD0111EN'],
#  406940: ['RP0101EN',
#   'BD0115EN',
#   'BD0111EN',
#   'BD0101EN',
#   'DS0101EN',
#   'BD0211EN'],
#  2061096: ['BD0211EN',
#   'CC0201EN',
#   'BD0111EN',
#   'BD0101EN',
#   'PY0101EN',
#   'DS0101EN'],
#  149690: ['BD0211EN',
#   'BC0101EN',
#   'BD0111EN',
#   'BD0115EN',
#   'BD0101EN',
#   'DS0101EN'],
#  1236864: ['BD0101EN',
#   'BD0115EN',
#   'CC0201EN',
#   'BD0211EN',
#   'CO0101EN',
#   'BD0111EN',
#   'DS0101EN'],
#  621497: ['BD0101EN', 'DS0101EN', 'BD0211EN'],
#  2082818: ['DV0101EN', 'BD0115EN'],
#  927022: ['BD0101EN',
#   'BD0211EN',
#   'BC0101EN',
#   'PY0101EN',
#   'BD0115EN',
#   'BD0111EN'],
#  1607052: ['CC0101EN', 'BD0111EN', 'ML0101ENv3', 'PY0101EN', 'BD0101EN'],
#  591984: ['PY0101EN', 'BD0101EN', 'DS0101EN'],
#  1864557: ['ML0115EN', 'RP0101EN', 'ML0101ENv3', 'PY0101EN'],
#  459415: ['BC0101EN',
#   'DS0101EN',
#   'DA0101EN',
#   'PY0101EN',
#   'CC0101EN',
#   'ML0115EN',
#   'RP0101EN',
#   'ML0101ENv3'],
#  1758635: ['DA0101EN', 'ML0115EN', 'ML0101ENv3', 'PY0101EN'],
#  630417: ['BD0211EN', 'BD0115EN', 'BD0101EN', 'BD0111EN', 'BC0101EN'],
#  922932: ['DS0101EN', 'BD0101EN', 'BC0101EN', 'RP0101EN', 'CO0201EN'],
#  1031032: ['PY0101EN', 'BD0101EN', 'BD0111EN', 'BD0211EN', 'CC0101EN'],
#  902617: ['RP0101EN',
#   'DS0101EN',
#   'CB0103EN',
#   'PY0101EN',
#   'BC0101EN',
#   'BD0101EN'],
#  1667543: ['CC0101EN', 'ML0115EN'],
#  572721: ['PY0101EN',
#   'RP0101EN',
#   'DA0101EN',
#   'DS0101EN',
#   'BD0111EN',
#   'BC0101EN',
#   'CB0103EN',
#   'ML0101ENv3'],
#  992171: ['DA0101EN',
#   'BD0211EN',
#   'PY0101EN',
#   'BD0111EN',
#   'ML0115EN',
#   'BD0115EN',
#   'CB0103EN',
#   'DV0101EN',
#   'BD0101EN',
#   'ML0101ENv3'],
#  2036996: ['ML0115EN'],
#  315714: ['ML0101ENv3',
#   'BD0211EN',
#   'DS0101EN',
#   'BD0111EN',
#   'ML0115EN',
#   'BD0101EN'],
#  569284: ['BD0111EN', 'BD0115EN', 'BD0211EN', 'BD0101EN'],
#  982945: ['BD0111EN', 'BD0101EN', 'BD0211EN'],
#  1660009: ['DV0101EN',
#   'PY0101EN',
#   'RP0101EN',
#   'CB0103EN',
#   'DA0101EN',
#   'DS0101EN',
#   'ML0101ENv3'],
#  425952: ['BD0101EN', 'BD0211EN'],
#  910687: ['RP0101EN',
#   'DS0101EN',
#   'ML0115EN',
#   'DA0101EN',
#   'PY0101EN',
#   'BD0111EN',
#   'BD0101EN'],
#  934060: ['PY0101EN', 'DA0101EN', 'DV0101EN'],
#  418401: ['PY0101EN', 'CO0101EN', 'BD0101EN', 'DS0101EN'],
#  700521: ['ML0115EN',
#   'BD0211EN',
#   'RP0101EN',
#   'PY0101EN',
#   'CO0201EN',
#   'DA0101EN',
#   'DS0101EN',
#   'BD0101EN',
#   'DV0101EN',
#   'BD0111EN'],
#  544738: ['BD0101EN',
#   'ML0115EN',
#   'DS0101EN',
#   'BD0111EN',
#   'BD0115EN',
#   'BD0211EN'],
#  1396750: ['PY0101EN', 'ML0115EN'],
#  765007: ['BD0101EN', 'PY0101EN', 'BD0111EN', 'DS0101EN'],
#  1085627: ['ML0115EN', 'CO0101EN', 'BC0101EN'],
#  779324: ['CO0201EN', 'PY0101EN', 'ML0115EN', 'DS0101EN', 'BD0111EN'],
#  1390701: ['ML0115EN', 'ML0101ENv3', 'PY0101EN'],
#  776333: ['BD0211EN',
#   'BD0111EN',
#   'DA0101EN',
#   'RP0101EN',
#   'DS0101EN',
#   'PY0101EN',
#   'BD0115EN',
#   'BD0101EN',
#   'DV0101EN'],
#  1581286: ['BD0211EN', 'BD0111EN', 'CC0101EN', 'BD0101EN'],
#  1803286: ['DS0101EN',
#   'PY0101EN',
#   'CC0101EN',
#   'DV0101EN',
#   'ML0101ENv3',
#   'DA0101EN',
#   'ML0115EN'],
#  70434: ['BD0111EN', 'BD0115EN', 'BD0101EN'],
#  620994: ['DS0101EN', 'BC0101EN', 'PY0101EN', 'BD0101EN'],
#  1051928: ['BC0101EN', 'CO0101EN', 'BD0101EN', 'CB0103EN', 'DS0101EN'],
#  1101622: ['ML0115EN',
#   'DS0101EN',
#   'DV0101EN',
#   'DA0101EN',
#   'ML0101ENv3',
#   'PY0101EN'],
#  964624: ['DS0101EN',
#   'BD0111EN',
#   'BD0115EN',
#   'BD0211EN',
#   'PY0101EN',
#   'BD0101EN',
#   'CC0201EN'],
#  1950381: ['CC0201EN', 'CC0101EN'],
#  497451: ['BD0101EN'],
#  1128883: ['DS0101EN',
#   'ML0101ENv3',
#   'DA0101EN',
#   'BD0101EN',
#   'DV0101EN',
#   'PY0101EN',
#   'RP0101EN',
#   'ML0115EN'],
#  52091: ['ML0101ENv3',
#   'ML0115EN',
#   'CC0201EN',
#   'DA0101EN',
#   'CC0101EN',
#   'CB0103EN',
#   'CO0201EN',
#   'BD0211EN',
#   'CO0101EN'],
#  2050073: ['DS0101EN', 'PY0101EN', 'CC0101EN', 'RP0101EN'],
#  757762: ['PY0101EN', 'BD0115EN', 'BD0101EN', 'BD0111EN', 'BD0211EN'],
#  1717953: ['BD0101EN',
#   'BC0101EN',
#   'DV0101EN',
#   'RP0101EN',
#   'CC0101EN',
#   'DS0101EN',
#   'DA0101EN',
#   'ML0101ENv3',
#   'ML0115EN',
#   'BD0111EN',
#   'PY0101EN'],
#  739171: ['BC0101EN',
#   'BD0211EN',
#   'PY0101EN',
#   'BD0111EN',
#   'BD0115EN',
#   'BD0101EN',
#   'DS0101EN'],
#  1021113: ['BD0111EN',
#   'BC0101EN',
#   'DS0101EN',
#   'CO0101EN',
#   'CO0201EN',
#   'CC0101EN',
#   'BD0101EN',
#   'ML0115EN'],
#  1255885: ['RP0101EN',
#   'DS0101EN',
#   'ML0115EN',
#   'BD0101EN',
#   'ML0101ENv3',
#   'CC0101EN',
#   'DV0101EN',
#   'CO0101EN'],
#  899011: ['BD0111EN', 'BD0101EN', 'BD0211EN', 'PY0101EN', 'BC0101EN'],
#  1562232: ['DA0101EN', 'ML0101ENv3', 'RP0101EN', 'PY0101EN'],
#  1738888: ['BD0101EN',
#   'DA0101EN',
#   'PY0101EN',
#   'DV0101EN',
#   'ML0101ENv3',
#   'BD0111EN'],
#  1803965: ['DS0101EN',
#   'ML0101ENv3',
#   'DV0101EN',
#   'DA0101EN',
#   'PY0101EN',
#   'ML0115EN',
#   'BD0101EN',
#   'CC0101EN',
#   'RP0101EN'],
#  1008504: ['DA0101EN',
#   'DS0101EN',
#   'CO0201EN',
#   'CB0103EN',
#   'BD0101EN',
#   'PY0101EN',
#   'CO0101EN'],
#  440679: ['PY0101EN',
#   'BC0101EN',
#   'BD0101EN',
#   'BD0115EN',
#   'BD0111EN',
#   'DS0101EN',
#   'RP0101EN'],
#  681785: ['PY0101EN',
#   'DV0101EN',
#   'DS0101EN',
#   'BC0101EN',
#   'ML0101ENv3',
#   'BD0111EN',
#   'BD0101EN',
#   'RP0101EN',
#   'DA0101EN'],
#  428830: ['BD0101EN', 'BD0111EN', 'BD0115EN', 'PY0101EN'],
#  1104367: ['BC0101EN', 'CO0101EN', 'PY0101EN', 'CO0201EN'],
#  1371316: ['DS0101EN', 'CB0103EN', 'DV0101EN', 'DA0101EN', 'PY0101EN'],
#  1840422: ['CC0101EN', 'BC0101EN', 'CO0101EN', 'CC0201EN'],
#  1823144: ['CC0201EN', 'DS0101EN', 'ML0101ENv3', 'CO0101EN'],
#  1271321: ['CO0201EN', 'PY0101EN', 'DS0101EN', 'CO0101EN'],
#  661906: ['BD0211EN',
#   'DA0101EN',
#   'RP0101EN',
#   'DV0101EN',
#   'BD0111EN',
#   'BD0101EN',
#   'PY0101EN',
#   'DS0101EN'],
#  1514188: ['BD0115EN',
#   'CC0201EN',
#   'CC0101EN',
#   'CO0101EN',
#   'PY0101EN',
#   'DV0101EN'],
#  667110: ['BD0111EN', 'BD0115EN', 'BD0101EN'],
#  447524: ['PY0101EN',
#   'BC0101EN',
#   'DA0101EN',
#   'DV0101EN',
#   'DS0101EN',
#   'ML0101ENv3',
#   'ML0115EN'],
#  483426: ['ML0115EN', 'BD0101EN', 'BD0115EN', 'BD0211EN', 'BD0111EN'],
#  1193731: ['BD0211EN', 'BD0111EN', 'BD0101EN', 'PY0101EN', 'DA0101EN'],
#  689540: ['BD0111EN', 'CC0201EN', 'DA0101EN', 'CC0101EN'],
#  779857: ['DV0101EN',
#   'CB0103EN',
#   'BD0101EN',
#   'BC0101EN',
#   'DA0101EN',
#   'DS0101EN',
#   'PY0101EN'],
#  1953163: ['DV0101EN',
#   'DA0101EN',
#   'BD0101EN',
#   'PY0101EN',
#   'DS0101EN',
#   'CC0101EN',
#   'CC0201EN',
#   'BD0111EN',
#   'BD0211EN',
#   'ML0115EN',
#   'ML0101ENv3'],
#  1145194: ['DA0101EN', 'BC0101EN', 'DV0101EN', 'PY0101EN'],
#  963178: ['DV0101EN', 'ML0101ENv3', 'DA0101EN', 'DS0101EN', 'PY0101EN'],
#  921347: ['DA0101EN',
#   'DV0101EN',
#   'ML0115EN',
#   'PY0101EN',
#   'ML0101ENv3',
#   'BD0115EN',
#   'BD0211EN',
#   'DS0101EN',
#   'RP0101EN',
#   'BD0101EN',
#   'CC0201EN',
#   'BD0111EN'],
#  647516: ['BD0101EN', 'BD0111EN', 'CB0103EN', 'BD0211EN', 'PY0101EN'],
#  1423135: ['DV0101EN',
#   'ML0101ENv3',
#   'PY0101EN',
#   'BD0101EN',
#   'DS0101EN',
#   'DA0101EN',
#   'RP0101EN'],
#  506734: ['BD0101EN', 'DS0101EN', 'BD0111EN'],
#  777750: ['PY0101EN', 'CO0201EN', 'CO0101EN', 'DS0101EN'],
#  881665: ['CC0101EN', 'BD0101EN', 'DS0101EN'],
#  246703: ['BD0211EN', 'BD0115EN', 'BD0101EN', 'ML0115EN', 'BD0111EN'],
#  1232030: ['RP0101EN',
#   'CO0201EN',
#   'BD0211EN',
#   'ML0115EN',
#   'CC0101EN',
#   'CO0101EN'],
#  1866295: ['CO0101EN'],
#  1427154: ['BD0111EN',
#   'PY0101EN',
#   'BD0211EN',
#   'DV0101EN',
#   'BD0115EN',
#   'BD0101EN',
#   'CO0101EN',
#   'DA0101EN'],
#  1099252: ['CO0101EN',
#   'CO0201EN',
#   'DS0101EN',
#   'CB0103EN',
#   'ML0101ENv3',
#   'PY0101EN'],
#  956089: ['PY0101EN',
#   'DA0101EN',
#   'CB0103EN',
#   'DS0101EN',
#   'DV0101EN',
#   'BC0101EN'],
#  1472511: ['DV0101EN', 'DA0101EN', 'ML0101ENv3', 'PY0101EN', 'DS0101EN'],
#  1977334: ['ML0101ENv3', 'DA0101EN', 'ML0115EN', 'DS0101EN', 'BD0111EN'],
#  464965: ['BD0101EN', 'BD0111EN'],
#  1696376: ['PY0101EN', 'DS0101EN'],
#  774617: ['BC0101EN', 'PY0101EN', 'BD0111EN', 'BD0101EN'],
#  691576: ['BD0111EN', 'BD0211EN', 'PY0101EN', 'BD0101EN'],
#  1314655: ['CB0103EN',
#   'DA0101EN',
#   'PY0101EN',
#   'CO0101EN',
#   'RP0101EN',
#   'DS0101EN',
#   'ML0101ENv3',
#   'BD0115EN',
#   'CO0201EN',
#   'BD0101EN',
#   'ML0115EN',
#   'BD0111EN',
#   'BD0211EN',
#   'DV0101EN'],
#  1083088: ['DV0101EN', 'DA0101EN', 'PY0101EN'],
#  687371: ['BD0101EN', 'DS0101EN', 'CB0103EN', 'PY0101EN'],
#  1384042: ['ML0115EN',
#   'BD0111EN',
#   'PY0101EN',
#   'DV0101EN',
#   'DA0101EN',
#   'ML0101ENv3',
#   'DS0101EN',
#   'BD0211EN'],
#  1229024: ['BD0111EN', 'BD0211EN', 'BD0101EN', 'PY0101EN'],
#  1871627: ['ML0101ENv3',
#   'PY0101EN',
#   'DS0101EN',
#   'CC0101EN',
#   'ML0115EN',
#   'CB0103EN'],
#  942027: ['PY0101EN', 'BD0111EN', 'BD0101EN', 'DS0101EN'],
#  876841: ['DS0101EN', 'BC0101EN', 'CC0101EN'],
#  998972: ['BD0211EN', 'BD0101EN', 'DS0101EN', 'BD0111EN'],
#  707328: ['DS0101EN', 'BD0101EN', 'PY0101EN', 'BC0101EN'],
#  462554: ['BD0101EN', 'BD0115EN', 'BD0211EN', 'BD0111EN'],
#  778132: ['BD0111EN',
#   'DV0101EN',
#   'PY0101EN',
#   'DS0101EN',
#   'ML0101ENv3',
#   'CO0101EN',
#   'BD0211EN',
#   'BD0101EN',
#   'DA0101EN'],
#  1627595: ['CB0103EN',
#   'PY0101EN',
#   'DA0101EN',
#   'DS0101EN',
#   'CC0101EN',
#   'DV0101EN'],
#  1628200: ['DS0101EN',
#   'BC0101EN',
#   'BD0101EN',
#   'ML0101ENv3',
#   'ML0115EN',
#   'PY0101EN'],
#  1019344: ['BD0211EN', 'DS0101EN', 'BD0111EN', 'BD0101EN', 'BD0115EN'],
#  969690: ['ML0115EN', 'DS0101EN'],
#  587229: ['BD0111EN',
#   'CC0101EN',
#   'DS0101EN',
#   'BD0211EN',
#   'RP0101EN',
#   'BD0101EN'],
#  718368: ['BD0101EN', 'BD0111EN', 'BD0115EN'],
#  1441107: ['PY0101EN', 'DA0101EN', 'ML0115EN', 'ML0101ENv3'],
#  964237: ['BC0101EN',
#   'DA0101EN',
#   'RP0101EN',
#   'ML0101ENv3',
#   'PY0101EN',
#   'DV0101EN',
#   'DS0101EN'],
#  1177066: ['BD0101EN', 'ML0115EN', 'BD0111EN', 'DS0101EN'],
#  511765: ['BC0101EN', 'DS0101EN', 'PY0101EN'],
#  1634015: ['ML0101ENv3',
#   'CB0103EN',
#   'DS0101EN',
#   'PY0101EN',
#   'DV0101EN',
#   'BD0101EN',
#   'ML0115EN',
#   'DA0101EN'],
#  1087982: ['BD0111EN',
#   'BD0211EN',
#   'PY0101EN',
#   'CO0101EN',
#   'ML0101ENv3',
#   'CO0201EN'],
#  1567706: ['DS0101EN', 'PY0101EN', 'BC0101EN'],
#  642609: ['DS0101EN', 'BD0101EN', 'BD0111EN', 'PY0101EN'],
#  552288: ['DS0101EN', 'CC0101EN'],
#  888784: ['DA0101EN', 'PY0101EN', 'ML0115EN', 'CB0103EN'],
#  1697610: ['DS0101EN',
#   'PY0101EN',
#   'DV0101EN',
#   'CB0103EN',
#   'CC0101EN',
#   'BD0101EN',
#   'DA0101EN'],
#  1513356: ['PY0101EN',
#   'ML0101ENv3',
#   'DA0101EN',
#   'DV0101EN',
#   'DS0101EN',
#   'ML0115EN',
#   'RP0101EN'],
#  491004: ['BD0211EN'],
#  1920814: ['ML0115EN', 'DA0101EN', 'RP0101EN', 'PY0101EN', 'DV0101EN'],
#  986814: ['PY0101EN', 'BD0101EN', 'BD0111EN', 'BD0211EN', 'DS0101EN'],
#  1115180: ['DA0101EN',
#   'ML0115EN',
#   'DS0101EN',
#   'PY0101EN',
#   'ML0101ENv3',
#   'DV0101EN'],
#  1824570: ['DS0101EN', 'ML0115EN', 'PY0101EN'],
#  354686: ['BD0115EN', 'CC0101EN', 'BD0111EN'],
#  888162: ['CB0103EN',
#   'ML0115EN',
#   'DV0101EN',
#   'RP0101EN',
#   'DS0101EN',
#   'PY0101EN',
#   'CO0101EN',
#   'DA0101EN',
#   'ML0101ENv3',
#   'BD0101EN'],
#  1018679: ['DV0101EN', 'PY0101EN', 'DA0101EN'],
#  1626145: ['CC0101EN', 'DS0101EN', 'BC0101EN'],
#  1393591: ['DV0101EN', 'DS0101EN', 'ML0101ENv3', 'PY0101EN'],
#  911798: ['DA0101EN', 'PY0101EN', 'DS0101EN', 'RP0101EN', 'DV0101EN'],
#  1040249: ['BC0101EN',
#   'PY0101EN',
#   'BD0211EN',
#   'RP0101EN',
#   'DA0101EN',
#   'BD0111EN',
#   'BD0115EN',
#   'ML0101ENv3',
#   'DV0101EN'],
#  1327565: ['PY0101EN', 'CC0101EN', 'DS0101EN', 'BD0101EN'],
#  1106139: ['CO0201EN', 'DV0101EN', 'CO0101EN'],
#  1766896: ['CO0101EN', 'CC0201EN', 'BD0111EN', 'CC0101EN'],
#  774978: ['BC0101EN', 'BD0101EN', 'CC0101EN', 'BD0211EN'],
#  905781: ['DV0101EN',
#   'BC0101EN',
#   'ML0115EN',
#   'BD0111EN',
#   'RP0101EN',
#   'DA0101EN',
#   'PY0101EN',
#   'DS0101EN',
#   'CB0103EN',
#   'BD0101EN'],
#  1368692: ['BD0111EN',
#   'BD0211EN',
#   'BC0101EN',
#   'DV0101EN',
#   'PY0101EN',
#   'DA0101EN',
#   'ML0101ENv3',
#   'BD0101EN',
#   'ML0115EN',
#   'DS0101EN'],
#  786514: ['BD0101EN', 'DS0101EN', 'PY0101EN', 'BD0111EN'],
#  37465: ['DS0101EN', 'BD0111EN', 'BD0101EN', 'BD0211EN', 'BD0115EN'],
#  1050603: ['CO0101EN', 'CO0201EN', 'BC0101EN'],
#  1018143: ['ML0101ENv3',
#   'BD0211EN',
#   'BD0111EN',
#   'BD0115EN',
#   'BD0101EN',
#   'CB0103EN',
#   'PY0101EN'],
#  550887: ['DS0101EN', 'PY0101EN', 'DA0101EN', 'DV0101EN', 'RP0101EN'],
#  431224: ['BD0101EN', 'BD0211EN', 'BD0111EN'],
#  926147: ['DS0101EN',
#   'CO0101EN',
#   'CO0201EN',
#   'CC0201EN',
#   'PY0101EN',
#   'BC0101EN',
#   'CB0103EN'],
#  1804257: ['DV0101EN', 'DA0101EN', 'PY0101EN', 'BD0111EN'],
#  446388: ['DV0101EN', 'BD0101EN', 'DA0101EN', 'PY0101EN', 'BD0111EN'],
#  795406: ['BD0211EN'],
#  1658936: ['ML0101ENv3',
#   'CC0101EN',
#   'RP0101EN',
#   'DS0101EN',
#   'BD0101EN',
#   'ML0115EN'],
#  551330: ['ML0101ENv3', 'DV0101EN', 'PY0101EN', 'DA0101EN'],
#  899822: ['ML0115EN', 'DA0101EN', 'PY0101EN', 'ML0101ENv3'],
#  1197018: ['CO0101EN', 'CO0201EN'],
#  545870: ['BD0101EN', 'CO0101EN', 'PY0101EN', 'DS0101EN'],
#  576061: ['DS0101EN',
#   'ML0115EN',
#   'DA0101EN',
#   'ML0101ENv3',
#   'RP0101EN',
#   'CB0103EN',
#   'PY0101EN'],
#  1357352: ['BD0101EN', 'BC0101EN', 'BD0211EN', 'DS0101EN', 'BD0111EN'],
#  261571: ['PY0101EN',
#   'ML0101ENv3',
#   'CC0201EN',
#   'DA0101EN',
#   'CC0101EN',
#   'BD0211EN',
#   'BD0101EN',
#   'ML0115EN',
#   'DS0101EN',
#   'DV0101EN',
#   'CO0201EN',
#   'BD0111EN'],
#  1486184: ['PY0101EN',
#   'DS0101EN',
#   'ML0101ENv3',
#   'CO0101EN',
#   'CO0201EN',
#   'DA0101EN',
#   'CC0201EN',
#   'CC0101EN',
#   'DV0101EN'],
#  1428322: ['BD0101EN',
#   'ML0101ENv3',
#   'PY0101EN',
#   'BD0211EN',
#   'BD0111EN',
#   'CO0101EN'],
#  435898: ['BD0111EN',
#   'CB0103EN',
#   'BD0115EN',
#   'BD0211EN',
#   'ML0115EN',
#   'BC0101EN'],
#  1713082: ['ML0115EN',
#   'BC0101EN',
#   'ML0101ENv3',
#   'DA0101EN',
#   'CC0201EN',
#   'PY0101EN',
#   'CO0101EN',
#   'DV0101EN'],
#  1109401: ['CC0101EN',
#   'DS0101EN',
#   'BC0101EN',
#   'ML0115EN',
#   'BD0101EN',
#   'PY0101EN'],
#  1029144: ['ML0115EN', 'DA0101EN', 'DV0101EN', 'ML0101ENv3', 'PY0101EN'],
#  1143528: ['DS0101EN', 'ML0101ENv3', 'PY0101EN', 'BD0101EN'],
#  782574: ['DS0101EN',
#   'CO0201EN',
#   'BC0101EN',
#   'BD0101EN',
#   'CO0101EN',
#   'CC0101EN'],
#  1562460: ['CO0101EN', 'BD0111EN', 'BD0101EN', 'BD0211EN'],
#  1455180: ['PY0101EN', 'BC0101EN', 'DA0101EN', 'DV0101EN', 'ML0101ENv3'],
#  924246: ['ML0115EN'],
#  476798: ['ML0115EN', 'PY0101EN', 'DA0101EN'],
#  918805: ['BD0111EN',
#   'PY0101EN',
#   'BD0211EN',
#   'RP0101EN',
#   'BD0115EN',
#   'BC0101EN'],
#  179356: ['BD0211EN',
#   'BD0115EN',
#   'DS0101EN',
#   'BD0111EN',
#   'BD0101EN',
#   'PY0101EN'],
#  1594142: ['DA0101EN', 'CC0101EN', 'PY0101EN', 'DS0101EN'],
#  542255: ['RP0101EN',
#   'PY0101EN',
#   'BD0111EN',
#   'BD0211EN',
#   'DS0101EN',
#   'BD0115EN',
#   'BD0101EN'],
#  1719220: ['DS0101EN', 'DV0101EN', 'PY0101EN', 'BD0101EN', 'DA0101EN'],
#  1129990: ['CC0101EN', 'CO0101EN', 'CO0201EN'],
#  1033465: ['DS0101EN',
#   'PY0101EN',
#   'DV0101EN',
#   'BD0101EN',
#   'RP0101EN',
#   'DA0101EN',
#   'ML0115EN',
#   'CB0103EN'],
#  1326774: ['DS0101EN', 'PY0101EN'],
#  585654: ['PY0101EN', 'DS0101EN', 'DA0101EN'],
#  1589197: ['BD0111EN', 'BD0101EN', 'BD0211EN', 'BD0115EN'],
#  1105494: ['BC0101EN', 'DS0101EN', 'ML0101ENv3', 'PY0101EN'],
#  1499434: ['CC0201EN', 'CC0101EN', 'PY0101EN'],
#  969644: ['PY0101EN', 'CB0103EN'],
#  1013378: ['ML0101ENv3',
#   'CB0103EN',
#   'BD0101EN',
#   'DV0101EN',
#   'DA0101EN',
#   'RP0101EN',
#   'PY0101EN'],
#  998681: ['CO0201EN', 'BD0101EN', 'BC0101EN', 'CC0101EN', 'CC0201EN'],
#  2056952: ['CC0101EN', 'BD0101EN', 'BD0111EN', 'BD0211EN', 'DS0101EN'],
#  932586: ['CB0103EN', 'DV0101EN', 'DS0101EN'],
#  477953: ['BD0111EN',
#   'ML0115EN',
#   'RP0101EN',
#   'BD0115EN',
#   'DS0101EN',
#   'BD0211EN'],
#  1643171: ['ML0115EN', 'BD0101EN', 'CC0101EN', 'DS0101EN'],
#  50348: ['PY0101EN',
#   'RP0101EN',
#   'DV0101EN',
#   'BD0111EN',
#   'CB0103EN',
#   'DS0101EN',
#   'BD0101EN'],
#  1468497: ['CC0201EN', 'CO0101EN', 'CC0101EN'],
#  1271384: ['ML0101ENv3',
#   'ML0115EN',
#   'BD0211EN',
#   'BD0111EN',
#   'DA0101EN',
#   'CO0101EN',
#   'RP0101EN'],
#  536821: ['DS0101EN', 'BD0111EN', 'BD0211EN', 'ML0115EN', 'BD0101EN'],
#  1691061: ['PY0101EN',
#   'DS0101EN',
#   'ML0101ENv3',
#   'ML0115EN',
#   'CC0101EN',
#   'DA0101EN'],
#  1242036: ['ML0115EN',
#   'ML0101ENv3',
#   'PY0101EN',
#   'DA0101EN',
#   'DV0101EN',
#   'DS0101EN',
#   'CC0101EN'],
#  403519: ['BD0111EN', 'DS0101EN', 'BD0115EN', 'BD0101EN'],
#  1336595: ['CC0201EN', 'DS0101EN', 'CC0101EN'],
#  914078: ['BD0101EN',
#   'DV0101EN',
#   'ML0101ENv3',
#   'DS0101EN',
#   'PY0101EN',
#   'CB0103EN',
#   'DA0101EN',
#   'RP0101EN'],
#  1203928: ['BC0101EN', 'PY0101EN', 'CO0101EN', 'DS0101EN', 'CC0101EN'],
#  457527: ['BD0101EN', 'DS0101EN', 'PY0101EN', 'RP0101EN', 'BD0111EN'],
#  1461432: ['ML0115EN',
#   'ML0101ENv3',
#   'RP0101EN',
#   'BC0101EN',
#   'BD0101EN',
#   'PY0101EN',
#   'CO0101EN'],
#  599839: ['ML0115EN',
#   'BD0211EN',
#   'PY0101EN',
#   'BD0111EN',
#   'RP0101EN',
#   'DS0101EN'],
#  1190880: ['PY0101EN', 'DA0101EN', 'DS0101EN'],
#  1718448: ['DS0101EN',
#   'PY0101EN',
#   'CC0101EN',
#   'RP0101EN',
#   'CB0103EN',
#   'BD0101EN'],
#  927126: ['DS0101EN',
#   'ML0115EN',
#   'DV0101EN',
#   'DA0101EN',
#   'RP0101EN',
#   'PY0101EN',
#   'BD0211EN'],
#  2074313: ['PY0101EN',
#   'DS0101EN',
#   'BD0111EN',
#   'DV0101EN',
#   'BD0211EN',
#   'DA0101EN',
#   'BD0101EN'],
#  757742: ['CO0101EN', 'CO0201EN', 'CB0103EN', 'RP0101EN'],
#  904667: ['DA0101EN',
#   'DV0101EN',
#   'PY0101EN',
#   'ML0101ENv3',
#   'DS0101EN',
#   'CB0103EN',
#   'BC0101EN'],
#  724221: ['CC0101EN', 'BD0111EN', 'PY0101EN', 'BD0101EN', 'DS0101EN'],
#  902488: ['BD0101EN', 'PY0101EN', 'DS0101EN'],
#  506042: ['BD0115EN', 'RP0101EN'],
#  1448499: ['DV0101EN',
#   'CC0201EN',
#   'DA0101EN',
#   'CC0101EN',
#   'PY0101EN',
#   'DS0101EN'],
#  739168: ['PY0101EN', 'BD0111EN', 'DS0101EN', 'BD0211EN', 'BD0101EN'],
#  781728: ['BD0111EN', 'BD0101EN', 'DS0101EN', 'CC0101EN'],
#  1322106: ['DV0101EN',
#   'BC0101EN',
#   'DS0101EN',
#   'DA0101EN',
#   'PY0101EN',
#   'BD0101EN'],
#  917605: ['ML0101ENv3',
#   'DS0101EN',
#   'PY0101EN',
#   'RP0101EN',
#   'BC0101EN',
#   'DV0101EN',
#   'DA0101EN'],
#  1411341: ['PY0101EN', 'DA0101EN', 'CC0101EN', 'CB0103EN', 'DV0101EN'],
#  691859: ['BD0101EN', 'RP0101EN'],
#  1354651: ['ML0101ENv3',
#   'BD0115EN',
#   'BD0111EN',
#   'PY0101EN',
#   'DS0101EN',
#   'BC0101EN',
#   'BD0101EN'],
#  1770354: ['DS0101EN', 'BC0101EN', 'ML0115EN'],
#  574414: ['BD0111EN', 'BD0115EN', 'ML0115EN', 'BD0211EN'],
#  968566: ['ML0115EN',
#   'PY0101EN',
#   'ML0101ENv3',
#   'BD0101EN',
#   'CB0103EN',
#   'BD0111EN',
#   'RP0101EN'],
#  1325797: ['CO0201EN',
#   'DS0101EN',
#   'ML0101ENv3',
#   'PY0101EN',
#   'CO0101EN',
#   'DV0101EN'],
#  1581358: ['BD0111EN', 'ML0101ENv3', 'PY0101EN', 'DS0101EN', 'BD0101EN'],
#  1643210: ['DA0101EN',
#   'BD0211EN',
#   'BD0101EN',
#   'PY0101EN',
#   'DS0101EN',
#   'BD0111EN'],
#  760278: ['CB0103EN',
#   'CO0101EN',
#   'CC0201EN',
#   'PY0101EN',
#   'BD0101EN',
#   'BD0211EN',
#   'DA0101EN',
#   'DS0101EN',
#   'BD0111EN'],
#  1126865: ['BC0101EN',
#   'CO0201EN',
#   'CC0201EN',
#   'CC0101EN',
#   'BD0101EN',
#   'CO0101EN'],
#  1271923: ['CB0103EN', 'PY0101EN', 'DA0101EN', 'DV0101EN'],
#  1294863: ['CO0201EN', 'CC0101EN', 'CC0201EN'],
#  1111747: ['CO0101EN',
#   'CC0101EN',
#   'CO0201EN',
#   'BD0101EN',
#   'BD0111EN',
#   'BD0211EN'],
#  887142: ['BD0101EN',
#   'PY0101EN',
#   'BD0211EN',
#   'BD0115EN',
#   'BD0111EN',
#   'ML0115EN'],
#  1092050: ['CO0101EN', 'BD0101EN', 'CC0201EN', 'BD0111EN', 'DS0101EN'],
#  889030: ['PY0101EN', 'ML0115EN', 'ML0101ENv3', 'DA0101EN'],
#  727462: ['BD0211EN',
#   'BD0115EN',
#   'BD0111EN',
#   'BD0101EN',
#   'RP0101EN',
#   'PY0101EN'],
#  1625299: ['ML0101ENv3', 'PY0101EN', 'DV0101EN', 'DA0101EN', 'CO0101EN'],
#  271899: ['BD0101EN', 'BD0115EN', 'BD0111EN'],
#  1045938: ['PY0101EN', 'DS0101EN', 'BD0101EN', 'ML0101ENv3'],
#  1180577: ['BD0101EN',
#   'ML0101ENv3',
#   'PY0101EN',
#   'BD0111EN',
#   'DA0101EN',
#   'DV0101EN'],
#  761540: ['DS0101EN',
#   'PY0101EN',
#   'CC0101EN',
#   'CO0101EN',
#   'DV0101EN',
#   'BD0111EN',
#   'CO0201EN',
#   'BD0101EN'],
#  1507787: ['CO0201EN', 'CO0101EN', 'CC0101EN'],
#  607999: ['ML0115EN', 'BD0111EN', 'CB0103EN', 'RP0101EN'],
#  1411199: ['BD0111EN', 'PY0101EN', 'DS0101EN', 'BD0101EN', 'CO0101EN'],
#  1019623: ['CC0101EN', 'DS0101EN', 'BD0101EN', 'BD0111EN'],
#  1497705: ['BD0111EN', 'BD0115EN', 'BD0211EN', 'BD0101EN'],
#  1641257: ['DV0101EN', 'PY0101EN', 'BD0101EN', 'ML0101ENv3', 'DS0101EN'],
#  426277: ['BD0101EN', 'BD0211EN', 'BD0111EN'],
#  1571316: ['BD0111EN', 'BD0101EN', 'ML0115EN', 'ML0101ENv3'],
#  1399082: ['PY0101EN', 'ML0101ENv3', 'ML0115EN'],
#  703067: ['ML0115EN',
#   'BD0211EN',
#   'DS0101EN',
#   'CC0101EN',
#   'CO0201EN',
#   'CO0101EN'],
#  1855847: ['CC0101EN', 'BD0101EN', 'CC0201EN'],
#  1267592: ['DS0101EN', 'PY0101EN', 'ML0101ENv3'],
#  1688004: ['DA0101EN',
#   'ML0101ENv3',
#   'RP0101EN',
#   'ML0115EN',
#   'PY0101EN',
#   'DV0101EN'],
#  1453903: ['ML0115EN', 'PY0101EN', 'ML0101ENv3'],
#  1179973: ['DS0101EN', 'BD0101EN', 'CC0101EN'],
#  739646: ['BC0101EN', 'PY0101EN', 'ML0101ENv3', 'BD0101EN', 'BD0111EN'],
#  1355350: ['DS0101EN', 'CO0201EN', 'CC0201EN'],
#  203388: ['DA0101EN', 'CC0101EN', 'CO0101EN', 'PY0101EN', 'DV0101EN'],
#  625486: ['CB0103EN',
#   'ML0115EN',
#   'DV0101EN',
#   'PY0101EN',
#   'DS0101EN',
#   'BD0111EN',
#   'BC0101EN',
#   'DA0101EN'],
#  1005259: ['CB0103EN',
#   'DS0101EN',
#   'BD0101EN',
#   'PY0101EN',
#   'DV0101EN',
#   'DA0101EN',
#   'BD0211EN',
#   'ML0115EN',
#   'ML0101ENv3',
#   'BD0111EN'],
#  1838639: ['CC0201EN'],
#  619829: ['BD0111EN', 'BD0211EN', 'PY0101EN', 'BD0101EN'],
#  746437: ['DS0101EN', 'PY0101EN', 'ML0115EN'],
#  364194: ['ML0115EN', 'RP0101EN', 'DS0101EN', 'BD0101EN'],
#  1435065: ['ML0101ENv3',
#   'DS0101EN',
#   'DV0101EN',
#   'ML0115EN',
#   'PY0101EN',
#   'DA0101EN'],
#  1229980: ['BD0101EN', 'BD0211EN', 'BD0111EN', 'DS0101EN'],
#  484628: ['BD0115EN', 'BD0111EN', 'BD0211EN'],
#  1265804: ['ML0101ENv3', 'CO0201EN', 'PY0101EN'],
#  600214: ['BD0101EN',
#   'BD0111EN',
#   'ML0115EN',
#   'PY0101EN',
#   'RP0101EN',
#   'DS0101EN'],
#  883019: ['CO0101EN',
#   'BC0101EN',
#   'ML0115EN',
#   'CO0201EN',
#   'ML0101ENv3',
#   'DA0101EN',
#   'DS0101EN'],
#  718688: ['ML0115EN',
#   'BD0101EN',
#   'DS0101EN',
#   'BD0111EN',
#   'BD0211EN',
#   'PY0101EN'],
#  643167: ['ML0115EN', 'DS0101EN', 'PY0101EN', 'BD0111EN', 'RP0101EN'],
#  998189: ['PY0101EN',
#   'DA0101EN',
#   'DV0101EN',
#   'DS0101EN',
#   'ML0115EN',
#   'ML0101ENv3',
#   'RP0101EN'],
#  1076032: ['PY0101EN', 'DS0101EN', 'CC0101EN'],
#  1655079: ['ML0101ENv3',
#   'PY0101EN',
#   'DV0101EN',
#   'RP0101EN',
#   'DA0101EN',
#   'DS0101EN'],
#  1069780: ['ML0101ENv3',
#   'CC0201EN',
#   'BC0101EN',
#   'DA0101EN',
#   'PY0101EN',
#   'ML0115EN',
#   'DV0101EN'],
#  943144: ['BD0101EN',
#   'BD0111EN',
#   'PY0101EN',
#   'DS0101EN',
#   'DV0101EN',
#   'DA0101EN',
#   'ML0115EN'],
#  1434413: ['DS0101EN', 'PY0101EN', 'ML0101ENv3'],
#  2074462: ['PY0101EN'],
#  717332: ['DA0101EN',
#   'PY0101EN',
#   'DV0101EN',
#   'ML0101ENv3',
#   'DS0101EN',
#   'CB0103EN',
#   'ML0115EN'],
#  1616745: ['ML0101ENv3',
#   'CC0101EN',
#   'DV0101EN',
#   'PY0101EN',
#   'DA0101EN',
#   'RP0101EN'],
#  988310: ['BD0211EN', 'BD0111EN'],
#  1691612: ['PY0101EN',
#   'ML0101ENv3',
#   'DV0101EN',
#   'CB0103EN',
#   'ML0115EN',
#   'DA0101EN'],
#  784385: ['DS0101EN', 'CC0101EN', 'BC0101EN', 'ML0101ENv3', 'BD0101EN'],
#  785533: ['DS0101EN', 'PY0101EN'],
#  1424123: ['CO0201EN', 'CC0101EN', 'BC0101EN'],
#  396776: ['BD0101EN', 'PY0101EN', 'BD0111EN', 'BD0115EN', 'BD0211EN'],
#  1061755: ['DS0101EN', 'CC0101EN', 'CO0201EN', 'CO0101EN', 'CC0201EN'],
#  1344036: ['DA0101EN',
#   'BD0111EN',
#   'DV0101EN',
#   'BD0101EN',
#   'ML0115EN',
#   'PY0101EN',
#   'DS0101EN',
#   'ML0101ENv3'],
#  1207973: ['CC0201EN', 'DS0101EN', 'CC0101EN', 'CO0101EN', 'ML0101ENv3'],
#  1395227: ['BD0211EN',
#   'BD0101EN',
#   'BD0115EN',
#   'BC0101EN',
#   'ML0101ENv3',
#   'BD0111EN',
#   'CC0101EN'],
#  641998: ['BD0101EN', 'ML0115EN', 'BD0111EN', 'BD0211EN'],
#  1776689: ['CC0101EN', 'CC0201EN', 'PY0101EN', 'BC0101EN', 'CO0101EN'],
#  1259402: ['BD0211EN', 'ML0101ENv3', 'BD0111EN', 'PY0101EN', 'BD0101EN'],
#  663689: ['CC0101EN',
#   'BD0101EN',
#   'CO0201EN',
#   'DS0101EN',
#   'PY0101EN',
#   'BC0101EN'],
#  1276534: ['DA0101EN',
#   'DS0101EN',
#   'ML0101ENv3',
#   'ML0115EN',
#   'DV0101EN',
#   'PY0101EN'],
#  1587923: ['ML0101ENv3', 'PY0101EN', 'DV0101EN', 'CB0103EN'],
#  471338: ['BD0111EN', 'BD0101EN'],
#  1228256: ['DV0101EN',
#   'ML0101ENv3',
#   'ML0115EN',
#   'PY0101EN',
#   'DS0101EN',
#   'CB0103EN'],
#  1622107: ['DS0101EN', 'ML0101ENv3', 'PY0101EN', 'ML0115EN', 'CC0101EN'],
#  774894: ['CB0103EN',
#   'DA0101EN',
#   'DV0101EN',
#   'PY0101EN',
#   'ML0101ENv3',
#   'BD0111EN',
#   'BD0115EN',
#   'CO0101EN',
#   'BD0101EN',
#   'DS0101EN'],
#  1082958: ['BC0101EN', 'BD0101EN', 'PY0101EN', 'BD0111EN'],
#  461359: ['PY0101EN',
#   'BD0211EN',
#   'DS0101EN',
#   'BD0101EN',
#   'DA0101EN',
#   'ML0101ENv3',
#   'BD0111EN'],
#  1092281: ['DA0101EN',
#   'DV0101EN',
#   'ML0101ENv3',
#   'BD0211EN',
#   'BD0101EN',
#   'BD0111EN'],
#  351320: ['BD0101EN', 'CB0103EN', 'BD0211EN'],
#  1632349: ['RP0101EN', 'BC0101EN', 'DS0101EN'],
#  1343288: ['BC0101EN',
#   'ML0115EN',
#   'RP0101EN',
#   'DV0101EN',
#   'PY0101EN',
#   'ML0101ENv3'],
#  1088239: ['ML0101ENv3', 'BD0211EN', 'BD0111EN', 'ML0115EN', 'BD0115EN'],
#  160015: ['BD0115EN', 'BD0211EN', 'BD0101EN', 'BD0111EN'],
#  914921: ['BD0211EN',
#   'BD0101EN',
#   'BD0111EN',
#   'CB0103EN',
#   'CO0101EN',
#   'PY0101EN',
#   'ML0115EN',
#   'ML0101ENv3',
#   'DS0101EN',
#   'RP0101EN'],
#  1308482: ['BD0101EN', 'PY0101EN'],
#  1764803: ['ML0101ENv3', 'BD0111EN', 'PY0101EN', 'ML0115EN'],
#  1408128: ['DS0101EN', 'DV0101EN', 'DA0101EN', 'PY0101EN'],
#  1107439: ['BC0101EN', 'CO0201EN', 'CO0101EN'],
#  613802: ['BD0101EN', 'ML0115EN', 'DS0101EN', 'BD0211EN'],
#  620075: ['BD0111EN', 'BD0211EN'],
#  1360773: ['DS0101EN', 'RP0101EN'],
#  314348: ['RP0101EN',
#   'BD0101EN',
#   'ML0101ENv3',
#   'DS0101EN',
#   'DV0101EN',
#   'PY0101EN',
#   'BD0111EN',
#   'DA0101EN'],
#  1086160: ['ML0115EN',
#   'BC0101EN',
#   'DA0101EN',
#   'ML0101ENv3',
#   'PY0101EN',
#   'DV0101EN'],
#  779505: ['DS0101EN',
#   'CO0101EN',
#   'ML0101ENv3',
#   'PY0101EN',
#   'CO0201EN',
#   'BC0101EN'],
#  1803385: ['DA0101EN',
#   'DS0101EN',
#   'ML0101ENv3',
#   'ML0115EN',
#   'PY0101EN',
#   'DV0101EN',
#   'CC0101EN'],
#  974620: ['CO0201EN', 'DS0101EN', 'CC0101EN', 'DA0101EN', 'PY0101EN'],
#  2000884: ['ML0101ENv3', 'ML0115EN', 'BD0211EN', 'PY0101EN', 'CO0101EN'],
#  951683: ['DS0101EN', 'CB0103EN', 'PY0101EN', 'ML0115EN'],
#  1315713: ['DS0101EN', 'PY0101EN', 'BD0101EN', 'DV0101EN', 'DA0101EN'],
#  1657304: ['PY0101EN', 'DV0101EN', 'ML0101ENv3', 'DA0101EN', 'DS0101EN'],
#  1339300: ['BC0101EN', 'PY0101EN', 'BD0101EN', 'DA0101EN', 'BD0111EN'],
#  581446: ['BD0101EN',
#   'BD0211EN',
#   'PY0101EN',
#   'DS0101EN',
#   'CB0103EN',
#   'BD0111EN',
#   'BC0101EN',
#   'RP0101EN'],
#  1463405: ['ML0115EN', 'PY0101EN', 'ML0101ENv3'],
#  1325764: ['BD0115EN', 'BD0111EN', 'PY0101EN'],
#  390213: ['BD0211EN', 'BD0101EN', 'BD0111EN'],
#  181124: ['BD0211EN', 'BD0101EN'],
#  778070: ['BD0211EN', 'ML0115EN', 'DS0101EN', 'BC0101EN', 'RP0101EN'],
#  1658021: ['BD0101EN',
#   'BC0101EN',
#   'BD0211EN',
#   'CO0201EN',
#   'DS0101EN',
#   'ML0101ENv3',
#   'BD0111EN',
#   'BD0115EN'],
#  435858: ['BD0111EN', 'BD0211EN', 'BD0101EN', 'BD0115EN'],
#  1864236: ['CC0201EN', 'ML0101ENv3', 'BC0101EN', 'ML0115EN'],
#  883395: ['BD0101EN', 'RP0101EN'],
#  1192496: ['BD0101EN', 'ML0101ENv3', 'CO0201EN'],
#  1888188: ['ML0115EN',
#   'PY0101EN',
#   'CC0201EN',
#   'DA0101EN',
#   'DS0101EN',
#   'DV0101EN'],
#  348808: ['RP0101EN', 'DS0101EN', 'BD0211EN', 'BD0111EN', 'BD0101EN'],
#  1138220: ['RP0101EN',
#   'PY0101EN',
#   'BD0111EN',
#   'DV0101EN',
#   'BD0211EN',
#   'BD0101EN',
#   'DA0101EN',
#   'ML0101ENv3',
#   'DS0101EN',
#   'CO0101EN'],
#  794942: ['BC0101EN', 'DS0101EN', 'BD0101EN', 'CC0101EN'],
#  1518203: ['DA0101EN',
#   'CB0103EN',
#   'DV0101EN',
#   'ML0101ENv3',
#   'DS0101EN',
#   'PY0101EN'],
#  1194704: ['DA0101EN',
#   'CO0101EN',
#   'PY0101EN',
#   'BD0111EN',
#   'CO0201EN',
#   'BC0101EN',
#   'CC0201EN'],
#  1600241: ['BD0111EN',
#   'CC0101EN',
#   'BD0115EN',
#   'BD0101EN',
#   'DS0101EN',
#   'BD0211EN'],
#  1547165: ['ML0101ENv3', 'DV0101EN', 'RP0101EN', 'DA0101EN', 'PY0101EN'],
#  1105350: ['PY0101EN', 'DS0101EN'],
#  1096927: ['DS0101EN', 'BD0101EN', 'CC0101EN'],
#  476115: ['BD0115EN',
#   'DS0101EN',
#   'BD0101EN',
#   'BD0211EN',
#   'RP0101EN',
#   'BD0111EN'],
#  1008900: ['ML0115EN', 'ML0101ENv3', 'PY0101EN'],
#  1672648: ['DA0101EN',
#   'PY0101EN',
#   'DS0101EN',
#   'ML0115EN',
#   'ML0101ENv3',
#   'DV0101EN',
#   'CC0101EN'],
#  1986311: ['PY0101EN',
#   'BD0101EN',
#   'DV0101EN',
#   'DA0101EN',
#   'CC0101EN',
#   'CO0101EN',
#   'DS0101EN',
#   'CC0201EN'],
#  1536959: ['BD0111EN', 'DS0101EN', 'BD0101EN'],
#  1864644: ['PY0101EN', 'ML0115EN', 'ML0101ENv3', 'DV0101EN', 'DA0101EN'],
#  983732: ['ML0115EN',
#   'PY0101EN',
#   'RP0101EN',
#   'DS0101EN',
#   'CC0201EN',
#   'ML0101ENv3'],
#  920511: ['BD0111EN', 'BD0101EN'],
#  881259: ['ML0115EN', 'BC0101EN', 'BD0101EN'],
#  1308093: ['BD0111EN', 'BD0211EN', 'DS0101EN', 'PY0101EN', 'BD0101EN'],
#  1044500: ['PY0101EN',
#   'DV0101EN',
#   'DA0101EN',
#   'ML0101ENv3',
#   'BD0101EN',
#   'BD0111EN'],
#  246282: ['PY0101EN', 'BD0211EN', 'DV0101EN', 'BD0111EN'],
#  1005000: ['RP0101EN',
#   'DS0101EN',
#   'PY0101EN',
#   'CC0201EN',
#   'CC0101EN',
#   'BC0101EN'],
#  984461: ['BD0115EN', 'BD0111EN', 'RP0101EN', 'BD0101EN', 'BD0211EN'],
#  1554610: ['PY0101EN', 'ML0101ENv3', 'ML0115EN'],
#  1076158: ['DS0101EN', 'DA0101EN', 'DV0101EN', 'PY0101EN'],
#  902409: ['BD0101EN'],
#  1656151: ['DV0101EN',
#   'DA0101EN',
#   'BD0101EN',
#   'DS0101EN',
#   'ML0101ENv3',
#   'CB0103EN'],
#  683043: ['CC0101EN', 'BD0101EN', 'PY0101EN', 'CO0201EN', 'BD0211EN'],
#  1107312: ['PY0101EN', 'ML0115EN', 'BD0101EN', 'DS0101EN', 'BC0101EN'],
#  1320948: ['CC0101EN', 'CC0201EN', 'BD0101EN', 'BC0101EN'],
#  1346186: ['PY0101EN',
#   'RP0101EN',
#   'DV0101EN',
#   'DS0101EN',
#   'BD0101EN',
#   'ML0101ENv3',
#   'BD0111EN'],
#  1313389: ['ML0115EN', 'ML0101ENv3', 'DS0101EN', 'DA0101EN', 'PY0101EN'],
#  1046814: ['BD0101EN', 'CC0101EN', 'BC0101EN'],
#  1607944: ['PY0101EN', 'DA0101EN', 'ML0101ENv3'],
#  1904245: ['DV0101EN', 'DA0101EN', 'ML0101ENv3', 'PY0101EN'],
#  1014837: ['ML0115EN',
#   'CB0103EN',
#   'BD0211EN',
#   'CC0201EN',
#   'DS0101EN',
#   'CC0101EN',
#   'CO0201EN',
#   'PY0101EN'],
#  1473132: ['PY0101EN', 'ML0101ENv3', 'BD0101EN', 'DA0101EN'],
#  1922237: ['CC0201EN', 'CC0101EN', 'CO0101EN'],
#  1281883: ['ML0101ENv3', 'PY0101EN'],
#  1543054: ['BC0101EN', 'DS0101EN', 'DA0101EN', 'ML0101ENv3', 'PY0101EN'],
#  759656: ['DS0101EN', 'BD0111EN', 'BD0101EN'],
#  1005934: ['DV0101EN',
#   'BC0101EN',
#   'ML0115EN',
#   'DA0101EN',
#   'PY0101EN',
#   'DS0101EN',
#   'CO0101EN',
#   'ML0101ENv3'],
#  1832234: ['DA0101EN', 'ML0101ENv3', 'PY0101EN', 'DV0101EN', 'DS0101EN'],
#  1568651: ['CO0101EN'],
#  1364743: ['CO0101EN', 'BD0111EN', 'BD0101EN', 'BD0211EN'],
#  1119439: ['CO0201EN',
#   'ML0115EN',
#   'CC0101EN',
#   'CO0101EN',
#   'ML0101ENv3',
#   'CC0201EN'],
#  769734: ['DS0101EN', 'BD0101EN', 'CC0101EN'],
#  1125553: ['DS0101EN',
#   'BD0211EN',
#   'BD0101EN',
#   'DA0101EN',
#   'BD0111EN',
#   'BC0101EN'],
#  1145420: ['BD0111EN', 'CO0201EN', 'CO0101EN'],
#  1832901: ['DS0101EN', 'CC0101EN', 'CC0201EN'],
#  1515909: ['DS0101EN', 'ML0101ENv3'],
#  1744047: ['BD0211EN',
#   'CO0101EN',
#   'BD0101EN',
#   'CC0101EN',
#   'BC0101EN',
#   'BD0111EN',
#   'DS0101EN',
#   'CC0201EN'],
#  1552450: ['DV0101EN',
#   'PY0101EN',
#   'CC0101EN',
#   'CB0103EN',
#   'DS0101EN',
#   'BD0101EN',
#   'CO0101EN',
#   'ML0101ENv3',
#   'DA0101EN'],
#  1461811: ['DS0101EN', 'CC0201EN', 'CC0101EN', 'PY0101EN'],
#  413286: ['BD0101EN', 'RP0101EN', 'DS0101EN', 'DA0101EN'],
#  1227873: ['PY0101EN', 'ML0101ENv3', 'CO0101EN', 'ML0115EN', 'CC0201EN'],
#  1808215: ['ML0115EN', 'ML0101ENv3', 'PY0101EN', 'DS0101EN', 'DV0101EN'],
#  1028691: ['BD0115EN', 'BD0111EN', 'BD0101EN'],
#  1107323: ['CC0101EN', 'CC0201EN', 'DS0101EN', 'BC0101EN'],
#  933539: ['DA0101EN',
#   'BD0101EN',
#   'BD0211EN',
#   'PY0101EN',
#   'BC0101EN',
#   'DS0101EN',
#   'BD0111EN'],
#  777203: ['DS0101EN', 'BC0101EN', 'BD0101EN', 'BD0111EN'],
#  786282: ['BD0101EN', 'BD0111EN', 'PY0101EN'],
#  1368592: ['DS0101EN', 'BD0111EN', 'BD0101EN', 'BD0211EN'],
#  284008: ['CO0101EN', 'CB0103EN'],
#  884576: ['DS0101EN',
#   'BD0101EN',
#   'DA0101EN',
#   'BD0211EN',
#   'DV0101EN',
#   'BD0111EN',
#   'PY0101EN'],
#  1227916: ['CO0101EN', 'PY0101EN', 'DV0101EN', 'DA0101EN'],
#  1301573: ['ML0101ENv3', 'BD0101EN', 'DS0101EN'],
#  1720300: ['BD0101EN',
#   'CC0101EN',
#   'ML0101ENv3',
#   'BD0111EN',
#   'ML0115EN',
#   'PY0101EN',
#   'DV0101EN',
#   'CO0101EN'],
#  1009985: ['CO0201EN', 'CC0101EN'],
#  403839: ['BD0115EN', 'BD0211EN', 'BD0111EN', 'BD0101EN'],
#  1699356: ['PY0101EN',
#   'DS0101EN',
#   'ML0115EN',
#   'BD0101EN',
#   'ML0101ENv3',
#   'DA0101EN',
#   'RP0101EN',
#   'CC0101EN'],
#  1360399: ['PY0101EN', 'CB0103EN', 'RP0101EN', 'ML0101ENv3', 'DA0101EN'],
#  1085199: ['DV0101EN', 'PY0101EN', 'BC0101EN', 'BD0111EN', 'DA0101EN'],
#  1231465: ['DS0101EN',
#   'BD0211EN',
#   'DA0101EN',
#   'BD0101EN',
#   'DV0101EN',
#   'BD0111EN',
#   'PY0101EN',
#   'ML0101ENv3',
#   'BC0101EN'],
#  1687045: ['DV0101EN', 'PY0101EN', 'DA0101EN', 'BD0101EN'],
#  629108: ['CO0101EN',
#   'BC0101EN',
#   'BD0101EN',
#   'DV0101EN',
#   'DA0101EN',
#   'DS0101EN',
#   'PY0101EN'],
#  1768789: ['ML0101ENv3', 'DV0101EN', 'DA0101EN', 'ML0115EN'],
#  666633: ['BD0211EN', 'BD0111EN', 'BD0115EN', 'BD0101EN'],
#  671203: ['BC0101EN', 'DS0101EN', 'BD0101EN'],
#  1637328: ['ML0101ENv3', 'PY0101EN', 'DA0101EN', 'CC0101EN', 'DV0101EN'],
#  1369842: ['CC0101EN', 'CO0201EN', 'CO0101EN'],
#  1574834: ['RP0101EN', 'CC0101EN', 'PY0101EN'],
#  1155304: ['CO0201EN', 'CO0101EN'],
#  1357226: ['CC0201EN', 'CC0101EN'],
#  573047: ['PY0101EN', 'DS0101EN', 'BD0111EN', 'BD0101EN'],
#  1650969: ['CC0101EN', 'DS0101EN', 'BD0101EN', 'ML0101ENv3', 'PY0101EN'],
#  1675314: ['BD0101EN', 'DS0101EN'],
#  1103515: ['DA0101EN', 'PY0101EN', 'DS0101EN', 'DV0101EN', 'BD0101EN'],
#  984164: ['DA0101EN', 'CO0201EN', 'PY0101EN', 'BD0111EN'],
#  343800: ['CO0201EN', 'PY0101EN', 'BD0101EN', 'ML0101ENv3', 'BC0101EN'],
#  376785: ['CO0201EN', 'DS0101EN', 'CC0201EN', 'BD0211EN', 'RP0101EN'],
#  784286: ['PY0101EN', 'RP0101EN'],
#  1020974: ['CO0101EN',
#   'ML0115EN',
#   'ML0101ENv3',
#   'CC0101EN',
#   'BD0101EN',
#   'BD0211EN',
#   'DA0101EN',
#   'PY0101EN',
#   'BD0111EN'],
#  978391: ['BD0101EN', 'DS0101EN', 'BC0101EN', 'PY0101EN'],
#  885498: ['BD0101EN'],
#  1522374: ['BD0111EN'],
#  1578344: ['DS0101EN', 'RP0101EN', 'CC0101EN', 'PY0101EN'],
#  1305655: ['DV0101EN',
#   'CC0201EN',
#   'CO0101EN',
#   'BD0111EN',
#   'BD0211EN',
#   'PY0101EN',
#   'ML0101ENv3',
#   'ML0115EN',
#   'DA0101EN',
#   'BD0101EN'],
#  1871037: ['DA0101EN', 'PY0101EN', 'ML0101ENv3', 'DS0101EN'],
#  1525360: ['CO0201EN',
#   'CC0101EN',
#   'CO0101EN',
#   'DS0101EN',
#   'CC0201EN',
#   'DV0101EN'],
#  1323058: ['PY0101EN', 'CC0101EN'],
#  1013489: ['CC0201EN', 'CO0101EN', 'CO0201EN'],
#  1356003: ['DA0101EN', 'ML0101ENv3', 'DV0101EN', 'RP0101EN', 'PY0101EN'],
#  1051348: ['BD0211EN',
#   'PY0101EN',
#   'BD0115EN',
#   'BC0101EN',
#   'BD0101EN',
#   'BD0111EN'],
#  435578: ['BD0101EN'],
#  1011733: ['BD0111EN', 'DS0101EN', 'BD0101EN', 'BC0101EN'],
#  542454: ['DS0101EN', 'RP0101EN', 'BC0101EN', 'BD0101EN', 'BD0111EN'],
#  696085: ['BD0115EN',
#   'BD0101EN',
#   'PY0101EN',
#   'BD0211EN',
#   'DS0101EN',
#   'CO0201EN',
#   'ML0101ENv3',
#   'DA0101EN',
#   'BD0111EN'],
#  559369: ['DS0101EN', 'PY0101EN', 'ML0115EN', 'BD0101EN'],
#  1560987: ['BC0101EN', 'BD0101EN', 'DS0101EN', 'CO0101EN'],
#  1454545: ['CO0201EN', 'CC0101EN', 'CO0101EN', 'CC0201EN'],
#  1016704: ['BD0211EN', 'DS0101EN', 'BD0115EN', 'BD0101EN'],
#  1079714: ['ML0101ENv3',
#   'DS0101EN',
#   'BD0111EN',
#   'PY0101EN',
#   'BD0101EN',
#   'ML0115EN'],
#  109915: ['BC0101EN', 'BD0111EN', 'PY0101EN'],
#  2012017: ['PY0101EN', 'DS0101EN', 'CC0101EN', 'BD0101EN', 'BD0111EN'],
#  887665: ['PY0101EN', 'BD0111EN', 'BD0211EN', 'BD0101EN', 'BD0115EN'],
#  1074342: ['DA0101EN',
#   'CO0101EN',
#   'DV0101EN',
#   'BC0101EN',
#   'DS0101EN',
#   'PY0101EN',
#   'ML0101ENv3',
#   'ML0115EN'],
#  1485705: ['DS0101EN', 'ML0115EN', 'BD0101EN', 'CO0101EN', 'CC0201EN'],
#  1468344: ['CO0101EN', 'BD0111EN', 'PY0101EN', 'BD0211EN', 'ML0101ENv3'],
#  1828981: ['CC0101EN', 'PY0101EN', 'ML0101ENv3', 'CC0201EN'],
#  529858: ['DS0101EN', 'BD0101EN', 'BD0211EN'],
#  1071340: ['CO0101EN', 'CO0201EN'],
#  1856259: ['BD0111EN', 'ML0115EN'],
#  1916042: ['ML0115EN', 'DA0101EN', 'DV0101EN', 'ML0101ENv3', 'PY0101EN'],
#  1665194: ['PY0101EN', 'BD0211EN', 'BD0101EN', 'BD0111EN'],
#  739825: ['BD0111EN',
#   'ML0115EN',
#   'DS0101EN',
#   'CB0103EN',
#   'PY0101EN',
#   'BD0101EN',
#   'CO0201EN'],
#  1935753: ['DS0101EN', 'PY0101EN', 'DA0101EN'],
#  1929807: ['BD0101EN', 'CO0101EN', 'CC0201EN', 'CC0101EN', 'DA0101EN'],
#  1456410: ['ML0101ENv3', 'ML0115EN', 'PY0101EN'],
#  1452402: ['BD0101EN', 'PY0101EN', 'BD0111EN'],
#  783842: ['BD0101EN', 'PY0101EN', 'DS0101EN', 'CC0101EN', 'BD0111EN'],
#  1570208: ['ML0115EN', 'ML0101ENv3', 'BD0101EN', 'BD0111EN'],
#  1855220: ['CC0201EN', 'CO0101EN'],
#  1730913: ['BD0211EN', 'BD0111EN', 'CC0201EN', 'CC0101EN'],
#  911976: ['BD0111EN', 'BD0211EN', 'BD0101EN', 'DS0101EN'],
#  1578616: ['CB0103EN', 'CC0201EN', 'PY0101EN', 'ML0101ENv3', 'CO0101EN'],
#  686896: ['PY0101EN',
#   'DA0101EN',
#   'BD0111EN',
#   'BD0101EN',
#   'RP0101EN',
#   'DS0101EN'],
#  1431506: ['CC0101EN', 'CC0201EN', 'CO0101EN', 'BC0101EN'],
#  988543: ['BD0101EN', 'DS0101EN'],
#  956675: ['DS0101EN'],
#  1396267: ['DS0101EN', 'DA0101EN', 'BC0101EN'],
#  978279: ['PY0101EN', 'DA0101EN', 'DV0101EN', 'DS0101EN'],
#  917017: ['DS0101EN', 'CB0103EN', 'BD0111EN', 'PY0101EN', 'ML0115EN'],
#  1151828: ['CB0103EN', 'CC0201EN', 'BC0101EN', 'CO0101EN'],
#  1049471: ['CO0201EN', 'DS0101EN', 'CO0101EN', 'BD0211EN'],
#  1730573: ['DS0101EN', 'PY0101EN', 'DA0101EN', 'DV0101EN'],
#  1380474: ['BD0101EN', 'DV0101EN'],
#  1858250: ['DS0101EN', 'DA0101EN', 'BD0211EN', 'BD0101EN'],
#  1139362: ['DA0101EN', 'BC0101EN', 'PY0101EN'],
#  921445: ['BD0101EN', 'BD0211EN', 'BD0111EN', 'DS0101EN'],
#  896192: ['ML0115EN',
#   'BD0101EN',
#   'DS0101EN',
#   'PY0101EN',
#   'ML0101ENv3',
#   'RP0101EN',
#   'CB0103EN'],
#  704583: ['DS0101EN', 'BD0101EN', 'BD0211EN', 'ML0115EN'],
#  161471: ['DS0101EN',
#   'BD0111EN',
#   'CC0201EN',
#   'CO0101EN',
#   'BD0101EN',
#   'PY0101EN'],
#  896335: ['ML0115EN', 'ML0101ENv3', 'BD0101EN'],
#  2000341: ['PY0101EN', 'BD0101EN', 'BD0211EN', 'BD0111EN', 'BD0115EN'],
#  373076: ['BD0115EN', 'BD0101EN', 'ML0115EN'],
#  1699606: ['CB0103EN', 'CC0101EN', 'ML0101ENv3', 'DA0101EN'],
#  1239926: ['BD0111EN',
#   'ML0101ENv3',
#   'RP0101EN',
#   'DA0101EN',
#   'CO0101EN',
#   'BD0101EN',
#   'PY0101EN'],
#  1132916: ['RP0101EN', 'BD0111EN', 'BD0101EN', 'CO0101EN', 'BD0211EN'],
#  1545628: ['BD0101EN', 'PY0101EN', 'BC0101EN', 'DS0101EN', 'ML0101ENv3'],
#  1238107: ['DS0101EN', 'PY0101EN', 'DA0101EN'],
#  1499966: ['DS0101EN',
#   'PY0101EN',
#   'DA0101EN',
#   'BD0211EN',
#   'DV0101EN',
#   'BD0111EN',
#   'ML0115EN'],
#  1063521: ['ML0101ENv3',
#   'PY0101EN',
#   'BD0101EN',
#   'DA0101EN',
#   'DS0101EN',
#   'CO0101EN',
#   'CO0201EN',
#   'DV0101EN'],
#  762066: ['RP0101EN', 'BD0101EN', 'CB0103EN', 'DS0101EN'],
#  1717303: ['BD0115EN', 'BD0111EN', 'DA0101EN', 'DV0101EN', 'PY0101EN'],
#  1799705: ['CC0201EN', 'DV0101EN', 'CC0101EN', 'PY0101EN', 'ML0101ENv3'],
#  503291: ['BD0115EN', 'BD0101EN', 'BD0111EN', 'BD0211EN'],
#  1234087: ['BD0211EN', 'BD0101EN', 'PY0101EN', 'BD0111EN'],
#  646861: ['BD0111EN', 'BD0211EN', 'BD0101EN', 'DS0101EN', 'BD0115EN'],
#  1616648: ['BD0111EN',
#   'CB0103EN',
#   'RP0101EN',
#   'DS0101EN',
#   'ML0101ENv3',
#   'PY0101EN',
#   'BD0101EN',
#   'CC0101EN'],
#  1196755: ['ML0101ENv3', 'PY0101EN', 'ML0115EN'],
#  1328233: ['DA0101EN', 'DV0101EN', 'ML0101ENv3', 'PY0101EN', 'ML0115EN'],
#  911789: ['BD0115EN', 'BD0101EN', 'CC0101EN', 'BD0211EN', 'BD0111EN'],
#  1897898: ['ML0101ENv3', 'PY0101EN', 'DA0101EN', 'ML0115EN'],
#  673206: ['DS0101EN', 'BD0211EN', 'BD0101EN', 'ML0115EN', 'BD0111EN'],
#  937026: ['DS0101EN', 'BD0211EN', 'BD0101EN', 'BD0111EN'],
#  1194346: ['ML0101ENv3', 'DA0101EN', 'BD0101EN'],
#  1000886: ['DA0101EN', 'PY0101EN', 'DV0101EN'],
#  1889420: ['DS0101EN', 'DA0101EN', 'PY0101EN', 'CC0101EN'],
#  1978886: ['DS0101EN', 'RP0101EN'],
#  1627236: ['CC0201EN', 'CC0101EN'],
#  732897: ['BD0115EN', 'BD0211EN', 'BD0111EN', 'BD0101EN'],
#  1287646: ['DV0101EN', 'PY0101EN', 'DA0101EN'],
#  1124048: ['ML0101ENv3', 'PY0101EN', 'ML0115EN', 'CO0101EN'],
#  486201: ['PY0101EN',
#   'ML0101ENv3',
#   'BD0111EN',
#   'BD0101EN',
#   'CB0103EN',
#   'DS0101EN'],
#  506202: ['DS0101EN'],
#  645459: ['BD0101EN', 'BD0111EN', 'BD0211EN'],
#  942261: ['BD0101EN', 'DS0101EN', 'PY0101EN'],
#  1278965: ['CC0101EN', 'PY0101EN', 'CO0101EN', 'CO0201EN', 'CC0201EN'],
#  891366: ['CO0101EN', 'DS0101EN'],
#  1955349: ['DV0101EN', 'PY0101EN', 'DS0101EN', 'DA0101EN'],
#  371091: ['CO0101EN', 'DS0101EN', 'PY0101EN'],
#  1664399: ['CC0101EN', 'PY0101EN'],
#  1431881: ['PY0101EN', 'DV0101EN', 'DS0101EN', 'DA0101EN'],
#  1840749: ['BD0111EN',
#   'ML0101ENv3',
#   'PY0101EN',
#   'BD0101EN',
#   'DA0101EN',
#   'BD0211EN',
#   'DV0101EN'],
#  1781984: ['BD0115EN', 'BD0111EN'],
#  1496810: ['BD0101EN', 'CO0101EN', 'ML0101ENv3', 'CC0101EN', 'CO0201EN'],
#  1578866: ['ML0115EN', 'DA0101EN', 'PY0101EN', 'ML0101ENv3', 'DV0101EN'],
#  926743: ['BD0211EN', 'BC0101EN', 'BD0111EN', 'BD0101EN'],
#  1887480: ['DA0101EN', 'CC0101EN', 'PY0101EN', 'DS0101EN', 'DV0101EN'],
#  609064: ['BD0101EN', 'PY0101EN', 'ML0115EN'],
#  728302: ['BD0111EN', 'BD0211EN', 'BD0101EN'],
#  2032910: ['DV0101EN',
#   'DS0101EN',
#   'DA0101EN',
#   'ML0115EN',
#   'ML0101ENv3',
#   'PY0101EN'],
#  1911140: ['PY0101EN', 'DS0101EN', 'BC0101EN'],
#  1256661: ['BD0101EN', 'BC0101EN', 'DS0101EN', 'BD0211EN', 'CO0101EN'],
#  1870948: ['CC0101EN', 'CC0201EN', 'BC0101EN', 'CO0101EN'],
#  1007060: ['CC0201EN',
#   'CO0201EN',
#   'BD0115EN',
#   'DS0101EN',
#   'CC0101EN',
#   'BD0211EN',
#   'BD0101EN',
#   'BD0111EN',
#   'PY0101EN'],
#  1758996: ['DV0101EN', 'ML0101ENv3', 'BD0101EN', 'DA0101EN', 'PY0101EN'],
#  720259: ['BD0211EN', 'ML0115EN', 'BD0111EN', 'BD0101EN'],
#  884472: ['CB0103EN', 'ML0115EN'],
#  1116126: ['BC0101EN', 'CO0201EN', 'CO0101EN', 'ML0115EN'],
#  1121636: ['PY0101EN', 'CC0101EN'],
#  576397: ['BD0101EN', 'BD0111EN', 'PY0101EN', 'DS0101EN', 'ML0101ENv3'],
#  1907898: ['PY0101EN', 'CO0101EN', 'ML0101ENv3'],
#  1021071: ['DS0101EN', 'DA0101EN', 'PY0101EN'],
#  625223: ['BD0101EN', 'DV0101EN', 'PY0101EN', 'DA0101EN'],
#  1830259: ['DV0101EN', 'BD0101EN'],
#  676094: ['DA0101EN',
#   'RP0101EN',
#   'BD0115EN',
#   'DS0101EN',
#   'BD0111EN',
#   'BD0101EN',
#   'BD0211EN'],
#  1076538: ['DS0101EN', 'BC0101EN'],
#  1871214: ['BD0211EN', 'DS0101EN', 'BD0111EN', 'BD0101EN'],
#  1474724: ['BD0111EN', 'DS0101EN', 'DA0101EN', 'BD0101EN'],
#  1344813: ['ML0101ENv3',
#   'DS0101EN',
#   'PY0101EN',
#   'BD0211EN',
#   'BD0101EN',
#   'BD0111EN'],
#  1847555: ['DV0101EN', 'DS0101EN'],
#  1669829: ['ML0101ENv3', 'DS0101EN', 'CC0101EN'],
#  481658: ['BD0111EN', 'BD0101EN'],
#  1341273: ['ML0101ENv3', 'CO0201EN', 'CC0201EN', 'PY0101EN', 'CO0101EN'],
#  884271: ['BD0111EN', 'BC0101EN', 'BD0101EN'],
#  630511: ['BD0111EN', 'BD0115EN', 'PY0101EN']}

# %%
recom_course = pd.DataFrame.from_dict(cluster_dict,orient='index').reset_index()
recom_course.rename(columns={'index':'user'},inplace=True)
recom_course.sort_values(by = 'user')
# Out:
#         user           0           1         2         3         4         5  \
# 307    37465    DS0101EN    BD0111EN  BD0101EN  BD0211EN  BD0115EN      None
# 355    50348    PY0101EN    RP0101EN  DV0101EN  BD0111EN  CB0103EN  DS0101EN
# 209    52091  ML0101ENv3    ML0115EN  CC0201EN  DA0101EN  CC0101EN  CB0103EN
# 201    70434    BD0111EN    BD0115EN  BD0101EN      None      None      None
# 19    108541    PY0101EN    BD0111EN  BD0115EN  BD0101EN  BD0211EN      None
# ..       ...         ...         ...       ...       ...       ...       ...
# 154  2057052    DS0101EN  ML0101ENv3  PY0101EN      None      None      None
# 164  2061096    BD0211EN    CC0201EN  BD0111EN  BD0101EN  PY0101EN  DS0101EN
# 371  2074313    PY0101EN    DS0101EN  BD0111EN  DV0101EN  BD0211EN  DA0101EN
# 443  2074462    PY0101EN        None      None      None      None      None
# 168  2082818    DV0101EN    BD0115EN      None      None      None      None
#
#             6         7         8     9    10    11    12    13
# 307      None      None      None  None  None  None  None  None
# 355  BD0101EN      None      None  None  None  None  None  None
# 209  CO0201EN  BD0211EN  CO0101EN  None  None  None  None  None
# 201      None      None      None  None  None  None  None  None
# 19       None      None      None  None  None  None  None  None
# ..        ...       ...       ...   ...   ...   ...   ...   ...
# 154      None      None      None  None  None  None  None  None
# 164      None      None      None  None  None  None  None  None
# 371  BD0101EN      None      None  None  None  None  None  None
# 443      None      None      None  None  None  None  None  None
# 168      None      None      None  None  None  None  None  None
#
# [732 rows x 15 columns]

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# * First of all, create a `user_subset` of  `test_users_labelled` where `test_users_labelled['user'] == user_id`.
# * Get the enrolled courses by  simply accessing `['item']` column of `user_subset`
# * Find its cluster label by accessing `['cluster']` column of `user_subset`. You can just use the first one (`.iloc[0]`) since every value in the column is the same for an individual user.
# * You can find all courses in the same cluster, by simply accessing `['item']` column of a subset of `test_users_labelled` where `test_users_labelled[test_users_labelled['cluster'] == cluster_id]`
# * You can find new/unseen courses to the user by taking a set difference between courses in cluster and enrolled_courses by using `.difference` method (dont forget to convert 2 lists in to sets before calling the method).
# * Use `courses_cluster` data set to find popularity of new/unseen courses and make unseen and popular courses as recommendation results for the user
#
# </details>

# %% [markdown]
# With the recommendation results, you also need to write some analytic code to answer the following two questions:

# %% [markdown]
# - On average, how many new/unseen courses have been recommended to each user?
# - What are the most frequently recommended courses? Return the top-10 commonly recommended courses across all users.

# %% [markdown]
# For example, suppose we have only 3 test users, each user receives the following recommendations:

# %% [markdown]
# - User1: ['course1', 'course2']
# - User2: ['course3', 'course4']
# - User3: ['course3', 'course4', 'course5']

# %% [markdown]
# Then, the average recommended courses per user is $(2 + 2 + 3) / 3 = 2.33$. The top-2 recommended courses are: `course3`: 2 times, and `course4`: 2 times.

# %% [markdown]
# Note that the answers will depend on how you compute the popular courses for each cluster. A lower threshold yields more recommended courses but with smaller confidence so that some test users may receive very long course recommendation lists and feel overwhelmed.
#
# Ideally, we should limit the maximum course recommendations for each user to be less than 20 courses per user.

# %% [markdown]
# ### Explore other clustering algorithms

# %% [markdown]
# As you have learned in previous unsupervised learning course, there are many other clustering algorithms such as `DBSCAN` and `Hierarchical Clustering`. You are encouraged to try them on the user profile feature vectors and compare the results with K-means.

# %% [markdown]
# ### Summary

# %% [markdown]
# Congratulations! In this lab, you have applied clustering algorithms to group users with similar interests and also tried PCA to reduce the dimensions of user feature vectors.
#
# Furthermore, with each user finding its learning interest group, you have also implemented clustering-based course recommender system to make recommendations based on his/her group members' popular courses choices.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Yan Luo](https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML321ENSkillsNetwork817-2022-01-01)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2021-10-25|1.0|Yan|Created the initial version|

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
